# %%
# Most importantly, select the kernal at least 3.11

# %%
import os, subprocess
import torch, struct, os, psutil, subprocess, time, threading
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import tensorflow as tf
import json, ezkl
import pandas as pd

from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# # DNN Models

# %% [markdown]
# ## Prepare

# %%
# Load TensorFlow MNIST data
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Convert to PyTorch tensors
test_images_pt = torch.tensor(test_images).float()
test_labels_pt = torch.tensor(test_labels)
# Flatten and normalize the images
test_images_pt = test_images_pt.view(-1, 28*28) / 255.0  # Flatten and normalize

# Assuming test_images_pt is your PyTorch tensor with shape [num_samples, 784]
test_images_pt_reshaped = test_images_pt.view(-1, 1, 28, 28)  # Reshape to [num_samples, channels, height, width]

# Downsample images
test_images_pt_downsampled = F.interpolate(test_images_pt_reshaped, size=(14, 14), mode='bilinear', align_corners=False)

# Flatten the images back to [num_samples, 14*14]
test_images_pt_downsampled = test_images_pt_downsampled.view(-1, 14*14)

# %%
def evaluate_pytorch_model(model, datasets, labels):
    # Create TensorDataset for test data
    test_dataset = TensorDataset(datasets, labels)
    # Create a DataLoader for the test dataset
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# %%
import subprocess, concurrent
import psutil
import time

def monitor_memory(pid, freq = 0.01):
    p = psutil.Process(pid)
    max_memory = 0
    while True:
        try:
            mem = p.memory_info().rss / (1024 * 1024)
            max_memory = max(max_memory, mem)
        except psutil.NoSuchProcess:
            break  # Process has finished
        time.sleep(freq)  # Poll every second
        
    #print(f"Maximum memory used: {max_memory} MB")
    return max_memory

def execute_and_monitor(command, show = False):
    start_time = time.time()
    process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        future = executor.submit(monitor_memory, process.pid)
        stdout, stderr = process.communicate()
        max_memory = future.result()
    if show:
        print(f"Maximum memory used: {max_memory} MB")
        print("Total time:", time.time() - start_time)
    return stdout, stderr, max_memory

# %%
def benchmark_dnn(test_images, predictions, model, mode = "resources", output_folder='./tmp/'):
    data_path = os.path.join(output_folder, 'input.json')
    model_path = os.path.join(output_folder, 'network.onnx')

    sampled_data = test_images[0]
    
    with torch.no_grad():
        torch.onnx.export(model, 
                    sampled_data, 
                    model_path, 
                    export_params=True, 
                    opset_version=10, 
                    do_constant_folding=True, 
                    input_names=['input_0'], 
                    output_names=['output'])
    loss = 0
    mem_usage = []
    time_cost = []
    benchmark_start_time = time.time()

    for i, img in enumerate(test_images):
        print ("Process for image", i)
        start_time = time.time()
        # Convert the tensor to numpy array and reshape it for JSON serialization
        x = (img.cpu().detach().numpy().reshape([-1])).tolist()
        data = dict(input_data = [x])

        # Serialize data into file:
        json.dump(data, open(data_path, 'w'))

        command = ["python", "gen_proof.py", "--model", model_path, "--data", data_path, "--output", output_folder, "--mode", mode]
        #subprocess.run(command)
        stdout, _, usage = execute_and_monitor(command)
        pred = int(stdout[-2])

        if pred != predictions[i]:
            loss += 1
            print ("Loss happens on index", i, "predicted_class", pred)
        mem_usage.append(usage)
        time_cost.append(time.time() - start_time)

    print ("Total time:", time.time() - benchmark_start_time)
    return loss, mem_usage, time_cost

# %%
def benchmark_cnn(test_images, predictions, model, mode = "resources", output_folder='./tmp/'):
    data_path = os.path.join(output_folder, 'input.json')
    model_path = os.path.join(output_folder, 'network.onnx')

    loss = 0
    mem_usage = []
    time_cost = []
    benchmark_start_time = time.time()

    for i in range(len(test_images)):
        print ("Process for image", i)
        start_time = time.time()
        img = test_images[i:i+1]
        with torch.no_grad():
            torch.onnx.export(model, 
                        img, 
                        model_path, 
                        export_params=True, 
                        opset_version=10, 
                        do_constant_folding=True, 
                        input_names=['input_0'], 
                        output_names=['output'])
        
        # Convert the tensor to numpy array and reshape it for JSON serialization
        # x = (img.cpu().detach().numpy().reshape([-1])).tolist()
        # data = dict(input_data = [x])

        # # Serialize data into file:
        # json.dump(data, open(data_path, 'w'))

        command = ["python", "gen_proof.py", "--model", model_path, "--data", data_path, "--output", output_folder, "--mode", mode]
        
        stdout, _, usage = execute_and_monitor(command)
        pred = int(stdout[-2])

        if pred != predictions[i]:
            loss += 1
            print ("Loss happens on index", i, "predicted_class", pred)
        mem_usage.append(usage)
        time_cost.append(time.time() - start_time)

    print ("Total time:", time.time() - benchmark_start_time)
    return loss, mem_usage, time_cost

# %%
csv_path = '../../benchmarks/benchmark_results.csv'

columns = ['Framework', 'Architecture', '# Layers', '# Parameters', 'Testing Size', 'Accuracy Loss (%)', 
           'Avg Memory Usage (MB)', 'Std Memory Usage', 'Avg Proving Time (s)', 'Std Proving Time']

# Check if the CSV file exists
if not os.path.isfile(csv_path):
    # Create a DataFrame with the specified columns
    df = pd.DataFrame(columns=columns)
    # Save the DataFrame as a CSV file
    df.to_csv(csv_path, index=False)
else:
    print(f"File '{csv_path}' already exists.")
# Out:
# File '../../benchmarks/benchmark_results.csv' already exists.

# %% [markdown]
# ## Benchmark for 196_25_10 DNN Model

# %%
# After login
arch_folder = "input-dense-dense/"
layers = [196,25,10]
model_name = "_".join([str(x) for x in layers])
model_path = "../../models/" + arch_folder + model_name

state_dict = torch.load(model_path + ".pth")

output_folder = './tmp/' + "_".join([str(x) for x in layers]) + "/"
os.makedirs(output_folder, exist_ok=True)

# %%
class Net(nn.Module):
    def __init__(self, num_classes=10):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(layers[0], layers[1])  # Flatten 
        self.fc2 = nn.Linear(layers[1], layers[2])  

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
    
model_pt = Net()
model_pt.load_state_dict(state_dict)
model_pt.eval()  # Set the model to evaluation mode

with torch.no_grad():  # Ensure gradients are not computed
    predictions = model_pt(test_images_pt_downsampled)
    predicted_labels = predictions.argmax(dim=1)

predicted_labels = predicted_labels.tolist()

# %%
# Evaluate the PyTorch model
accuracy = evaluate_pytorch_model(model_pt, test_images_pt_downsampled, test_labels_pt)
print(f'Accuracy of the PyTorch model on the test images: {accuracy:.8f}%')
# Out:
# Accuracy of the PyTorch model on the test images: 95.41000000%

# %% [markdown]
# ### Benchmark (resource mode)

# %%
test_size = 10
loss_, mem_usage_, time_cost_ = benchmark_dnn(test_images_pt_downsampled[:test_size], predicted_labels[:test_size], model_pt)
# Out:
# Process for image 0
# Process for image 1
# Process for image 2
# Process for image 3
# Process for image 4
# Process for image 5
# Process for image 6
# Process for image 7
# Process for image 8
# Process for image 9
# Total time: 7.243288040161133
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
new_row = {
    'Framework': ['ezkl (pytorch)'],
    'Architecture': ['Input-Dense-Dense (196x25x10'],
    '# Layers': [3],
    '# Parameters': [5185],
    'Testing Size': [test_size],
    'Accuracy Loss (%)': [loss_/test_size*100],
    'Avg Memory Usage (MB)': [sum(mem_usage_) / len(mem_usage_)],
    'Std Memory Usage': [pd.Series(mem_usage_).std()],
    'Avg Proving Time (s)': [sum(time_cost_) / len(time_cost_)],
    'Std Proving Time': [pd.Series(time_cost_).std()]
}

new_row_df = pd.DataFrame(new_row)

# %%
df = pd.read_csv(csv_path)

df = pd.concat([df, new_row_df], ignore_index=True)
df.to_csv(csv_path, index=False)
df
# Out:
#                    Framework                           Architecture  # Layers  \
# 0             opml (pytorch)          Input-Dense-Dense (196x25x10)         3
# 1             opml (pytorch)          Input-Dense-Dense (784x56x10)         3
# 2             opml (pytorch)  Input-Dense-Dense-Dense (196x24x14x10         4
# 3  circomlib-ml (tensorflow)          Input-Dense-Dense (196x25x10)         3
# 4  circomlib-ml (tensorflow)           Input-Dense-Dense (784x56x10         3
# 5          zkml (tensorflow)          Input-Dense-Dense (196x25x10)         3
# 6          zkml (tensorflow)          Input-Dense-Dense (784x56x10)         3
# 7          zkml (tensorflow)        Input-Dense-Dense (196x24x14x10         4
# 8             ezkl (pytorch)           Input-Dense-Dense (196x25x10         3
#
#    # Parameters  Testing Size  Accuracy Loss (%)  Avg Memory Usage (MB)  \
# 0          5185          5000               3.52              74.351948
# 1         44543          2500               0.72              89.120883
# 2          5228          5000               3.42              74.450789
# 3          5185          2500               0.00             998.735128
# 4         44543          2500               0.04            2328.322411
# 5          5185          1000               0.10            2334.295629
# 6         44543          1000               0.00            2357.363156
# 7          5228          2500               0.00            2338.480847
# 8          5185         10000               4.11              91.608069
#
#    Std Memory Usage  Avg Proving Time (s)  Std Proving Time
# 0          1.419725              0.809440          0.074357
# 1          2.254392              3.609974          0.421732
# 2          1.491530              0.829767          0.085084
# 3          8.040170              1.169482          0.108491
# 4         34.436486              2.351284          0.147113
# 5         12.335301             21.263430          0.294183
# 6         11.750076             22.012543          0.317096
# 7         13.611456             22.168541          0.528263
# 8          0.756873              0.660479          0.025701

# %% [markdown]
# ### Benchmark (accuracy mode)

# %%
test_size = 1000
loss_, mem_usage_, time_cost_ = benchmark_dnn(test_images_pt_downsampled[:test_size], predicted_labels[:test_size], model_pt, mode="accuracy")
# Out:
# Process for image 0
# Process for image 1
# Process for image 2
# Process for image 3
# Process for image 4
# Process for image 5
# Process for image 6
# Process for image 7
# Process for image 8
# Process for image 9
# Process for image 10
# Process for image 11
# Process for image 12
# Process for image 13
# Process for image 14
# Process for image 15
# Process for image 16
# Process for image 17
# Process for image 18
# Process for image 19
# Process for image 20
# Process for image 21
# Process for image 22
# Process for image 23
# Process for image 24
# Process for image 25
# Process for image 26
# Process for image 27
# Process for image 28
# Process for image 29
# Process for image 30
# Process for image 31
# Process for image 32
# Process for image 33
# Process for image 34
# Process for image 35
# Process for image 36
# Process for image 37
# Process for image 38
# Process for image 39
# Process for image 40
# Process for image 41
# Process for image 42
# Process for image 43
# Process for image 44
# Process for image 45
# Process for image 46
# Process for image 47
# Process for image 48
# Process for image 49
# Process for image 50
# Process for image 51
# Process for image 52
# Process for image 53
# Process for image 54
# Process for image 55
# Process for image 56
# Process for image 57
# Process for image 58
# Process for image 59
# Process for image 60
# Process for image 61
# Process for image 62
# Process for image 63
# Process for image 64
# Process for image 65
# Process for image 66
# Process for image 67
# Process for image 68
# Process for image 69
# Process for image 70
# Process for image 71
# Process for image 72
# Process for image 73
# Process for image 74
# Process for image 75
# Process for image 76
# Process for image 77
# Process for image 78
# Process for image 79
# Process for image 80
# Process for image 81
# Process for image 82
# Process for image 83
# Process for image 84
# Process for image 85
# Process for image 86
# Process for image 87
# Process for image 88
# Process for image 89
# Process for image 90
# Process for image 91
# Process for image 92
# Process for image 93
# Process for image 94
# Process for image 95
# Process for image 96
# Process for image 97
# Process for image 98
# Process for image 99
# Process for image 100
# Process for image 101
# Process for image 102
# Process for image 103
# Process for image 104
# Process for image 105
# Process for image 106
# Process for image 107
# Process for image 108
# Process for image 109
# Process for image 110
# Process for image 111
# Process for image 112
# Process for image 113
# Process for image 114
# Process for image 115
# Process for image 116
# Process for image 117
# Process for image 118
# Process for image 119
# Process for image 120
# Process for image 121
# Process for image 122
# Process for image 123
# Process for image 124
# Process for image 125
# Process for image 126
# Process for image 127
# Process for image 128
# Process for image 129
# Process for image 130
# Process for image 131
# Process for image 132
# Process for image 133
# Process for image 134
# Process for image 135
# Process for image 136
# Process for image 137
# Process for image 138
# Process for image 139
# Process for image 140
# Process for image 141
# Process for image 142
# Process for image 143
# Process for image 144
# Process for image 145
# Process for image 146
# Process for image 147
# Process for image 148
# Process for image 149
# Process for image 150
# Process for image 151
# Process for image 152
# Process for image 153
# Process for image 154
# Process for image 155
# Process for image 156
# Process for image 157
# Process for image 158
# Process for image 159
# Process for image 160
# Process for image 161
# Process for image 162
# Process for image 163
# Process for image 164
# Process for image 165
# Process for image 166
# Process for image 167
# Process for image 168
# Process for image 169
# Process for image 170
# Process for image 171
# Process for image 172
# Process for image 173
# Process for image 174
# Process for image 175
# Process for image 176
# Process for image 177
# Process for image 178
# Process for image 179
# Process for image 180
# Process for image 181
# Process for image 182
# Process for image 183
# Process for image 184
# Process for image 185
# Process for image 186
# Process for image 187
# Process for image 188
# Process for image 189
# Process for image 190
# Process for image 191
# Process for image 192
# Process for image 193
# Process for image 194
# Process for image 195
# Process for image 196
# Process for image 197
# Process for image 198
# Process for image 199
# Process for image 200
# Process for image 201
# Process for image 202
# Process for image 203
# Process for image 204
# Process for image 205
# Process for image 206
# Process for image 207
# Process for image 208
# Process for image 209
# Process for image 210
# Process for image 211
# Process for image 212
# Process for image 213
# Process for image 214
# Process for image 215
# Process for image 216
# Process for image 217
# Process for image 218
# Process for image 219
# Process for image 220
# Process for image 221
# Process for image 222
# Process for image 223
# Process for image 224
# Process for image 225
# Process for image 226
# Process for image 227
# Process for image 228
# Process for image 229
# Process for image 230
# Process for image 231
# Process for image 232
# Process for image 233
# Process for image 234
# Process for image 235
# Process for image 236
# Process for image 237
# Process for image 238
# Process for image 239
# Process for image 240
# Process for image 241
# Process for image 242
# Process for image 243
# Process for image 244
# Process for image 245
# Process for image 246
# Process for image 247
# Process for image 248
# Process for image 249
# Process for image 250
# Process for image 251
# Process for image 252
# Process for image 253
# Process for image 254
# Process for image 255
# Process for image 256
# Process for image 257
# Process for image 258
# Process for image 259
# Process for image 260
# Process for image 261
# Process for image 262
# Process for image 263
# Process for image 264
# Process for image 265
# Process for image 266
# Process for image 267
# Process for image 268
# Process for image 269
# Process for image 270
# Process for image 271
# Process for image 272
# Process for image 273
# Process for image 274
# Process for image 275
# Process for image 276
# Process for image 277
# Process for image 278
# Process for image 279
# Process for image 280
# Process for image 281
# Process for image 282
# Process for image 283
# Process for image 284
# Process for image 285
# Process for image 286
# Process for image 287
# Process for image 288
# Process for image 289
# Process for image 290
# Process for image 291
# Process for image 292
# Process for image 293
# Process for image 294
# Process for image 295
# Process for image 296
# Process for image 297
# Process for image 298
# Process for image 299
# Process for image 300
# Process for image 301
# Process for image 302
# Process for image 303
# Process for image 304
# Process for image 305
# Process for image 306
# Process for image 307
# Process for image 308
# Process for image 309
# Process for image 310
# Process for image 311
# Process for image 312
# Process for image 313
# Process for image 314
# Process for image 315
# Process for image 316
# Process for image 317
# Process for image 318
# Process for image 319
# Process for image 320
# Process for image 321
# Process for image 322
# Process for image 323
# Process for image 324
# Process for image 325
# Process for image 326
# Process for image 327
# Process for image 328
# Process for image 329
# Process for image 330
# Process for image 331
# Process for image 332
# Process for image 333
# Process for image 334
# Process for image 335
# Process for image 336
# Process for image 337
# Process for image 338
# Process for image 339
# Process for image 340
# Process for image 341
# Process for image 342
# Process for image 343
# Process for image 344
# Process for image 345
# Process for image 346
# Process for image 347
# Process for image 348
# Process for image 349
# Process for image 350
# Process for image 351
# Process for image 352
# Process for image 353
# Process for image 354
# Process for image 355
# Process for image 356
# Process for image 357
# Process for image 358
# Process for image 359
# Process for image 360
# Process for image 361
# Process for image 362
# Process for image 363
# Process for image 364
# Process for image 365
# Process for image 366
# Process for image 367
# Process for image 368
# Process for image 369
# Process for image 370
# Process for image 371
# Process for image 372
# Process for image 373
# Process for image 374
# Process for image 375
# Process for image 376
# Process for image 377
# Process for image 378
# Process for image 379
# Process for image 380
# Process for image 381
# Process for image 382
# Process for image 383
# Process for image 384
# Process for image 385
# Process for image 386
# Process for image 387
# Process for image 388
# Process for image 389
# Process for image 390
# Process for image 391
# Process for image 392
# Process for image 393
# Process for image 394
# Process for image 395
# Process for image 396
# Process for image 397
# Process for image 398
# Process for image 399
# Process for image 400
# Process for image 401
# Process for image 402
# Process for image 403
# Process for image 404
# Process for image 405
# Process for image 406
# Process for image 407
# Process for image 408
# Process for image 409
# Process for image 410
# Process for image 411
# Process for image 412
# Process for image 413
# Process for image 414
# Process for image 415
# Process for image 416
# Process for image 417
# Process for image 418
# Process for image 419
# Process for image 420
# Process for image 421
# Process for image 422
# Process for image 423
# Process for image 424
# Process for image 425
# Process for image 426
# Process for image 427
# Process for image 428
# Process for image 429
# Process for image 430
# Process for image 431
# Process for image 432
# Process for image 433
# Process for image 434
# Process for image 435
# Process for image 436
# Process for image 437
# Process for image 438
# Process for image 439
# Process for image 440
# Process for image 441
# Process for image 442
# Process for image 443
# Process for image 444
# Process for image 445
# Process for image 446
# Process for image 447
# Process for image 448
# Process for image 449
# Process for image 450
# Process for image 451
# Process for image 452
# Process for image 453
# Process for image 454
# Process for image 455
# Process for image 456
# Process for image 457
# Process for image 458
# Process for image 459
# Process for image 460
# Process for image 461
# Process for image 462
# Process for image 463
# Process for image 464
# Process for image 465
# Process for image 466
# Process for image 467
# Process for image 468
# Process for image 469
# Process for image 470
# Process for image 471
# Process for image 472
# Process for image 473
# Process for image 474
# Process for image 475
# Process for image 476
# Process for image 477
# Process for image 478
# Process for image 479
# Process for image 480
# Process for image 481
# Process for image 482
# Process for image 483
# Process for image 484
# Process for image 485
# Process for image 486
# Process for image 487
# Process for image 488
# Process for image 489
# Process for image 490
# Process for image 491
# Process for image 492
# Process for image 493
# Process for image 494
# Process for image 495
# Process for image 496
# Process for image 497
# Process for image 498
# Process for image 499
# Process for image 500
# Process for image 501
# Process for image 502
# Process for image 503
# Process for image 504
# Process for image 505
# Process for image 506
# Process for image 507
# Process for image 508
# Process for image 509
# Process for image 510
# Process for image 511
# Process for image 512
# Process for image 513
# Process for image 514
# Process for image 515
# Process for image 516
# Process for image 517
# Process for image 518
# Process for image 519
# Process for image 520
# Process for image 521
# Process for image 522
# Process for image 523
# Process for image 524
# Process for image 525
# Process for image 526
# Process for image 527
# Process for image 528
# Process for image 529
# Process for image 530
# Process for image 531
# Process for image 532
# Process for image 533
# Process for image 534
# Process for image 535
# Process for image 536
# Process for image 537
# Process for image 538
# Process for image 539
# Process for image 540
# Process for image 541
# Process for image 542
# Process for image 543
# Process for image 544
# Process for image 545
# Process for image 546
# Process for image 547
# Process for image 548
# Process for image 549
# Process for image 550
# Process for image 551
# Process for image 552
# Process for image 553
# Process for image 554
# Process for image 555
# Process for image 556
# Process for image 557
# Process for image 558
# Process for image 559
# Process for image 560
# Process for image 561
# Process for image 562
# Process for image 563
# Process for image 564
# Process for image 565
# Process for image 566
# Process for image 567
# Process for image 568
# Process for image 569
# Process for image 570
# Process for image 571
# Process for image 572
# Process for image 573
# Process for image 574
# Process for image 575
# Process for image 576
# Process for image 577
# Process for image 578
# Process for image 579
# Process for image 580
# Process for image 581
# Process for image 582
# Process for image 583
# Process for image 584
# Process for image 585
# Process for image 586
# Process for image 587
# Process for image 588
# Process for image 589
# Process for image 590
# Process for image 591
# Process for image 592
# Process for image 593
# Process for image 594
# Process for image 595
# Process for image 596
# Process for image 597
# Process for image 598
# Process for image 599
# Process for image 600
# Process for image 601
# Process for image 602
# Process for image 603
# Process for image 604
# Process for image 605
# Process for image 606
# Process for image 607
# Process for image 608
# Process for image 609
# Process for image 610
# Process for image 611
# Process for image 612
# Process for image 613
# Process for image 614
# Process for image 615
# Process for image 616
# Process for image 617
# Process for image 618
# Process for image 619
# Process for image 620
# Process for image 621
# Process for image 622
# Process for image 623
# Process for image 624
# Process for image 625
# Process for image 626
# Process for image 627
# Process for image 628
# Process for image 629
# Process for image 630
# Process for image 631
# Process for image 632
# Process for image 633
# Process for image 634
# Process for image 635
# Process for image 636
# Process for image 637
# Process for image 638
# Process for image 639
# Process for image 640
# Process for image 641
# Process for image 642
# Process for image 643
# Process for image 644
# Process for image 645
# Process for image 646
# Process for image 647
# Process for image 648
# Process for image 649
# Process for image 650
# Process for image 651
# Process for image 652
# Process for image 653
# Process for image 654
# Process for image 655
# Process for image 656
# Process for image 657
# Process for image 658
# Process for image 659
# Process for image 660
# Process for image 661
# Process for image 662
# Process for image 663
# Process for image 664
# Process for image 665
# Process for image 666
# Process for image 667
# Process for image 668
# Process for image 669
# Process for image 670
# Process for image 671
# Process for image 672
# Process for image 673
# Process for image 674
# Process for image 675
# Process for image 676
# Process for image 677
# Process for image 678
# Process for image 679
# Process for image 680
# Process for image 681
# Process for image 682
# Process for image 683
# Process for image 684
# Process for image 685
# Process for image 686
# Process for image 687
# Process for image 688
# Process for image 689
# Process for image 690
# Process for image 691
# Process for image 692
# Process for image 693
# Process for image 694
# Process for image 695
# Process for image 696
# Process for image 697
# Process for image 698
# Process for image 699
# Process for image 700
# Process for image 701
# Process for image 702
# Process for image 703
# Process for image 704
# Process for image 705
# Process for image 706
# Process for image 707
# Process for image 708
# Process for image 709
# Process for image 710
# Process for image 711
# Process for image 712
# Process for image 713
# Process for image 714
# Process for image 715
# Process for image 716
# Process for image 717
# Process for image 718
# Process for image 719
# Process for image 720
# Process for image 721
# Process for image 722
# Process for image 723
# Process for image 724
# Process for image 725
# Process for image 726
# Process for image 727
# Process for image 728
# Process for image 729
# Process for image 730
# Process for image 731
# Process for image 732
# Process for image 733
# Process for image 734
# Process for image 735
# Process for image 736
# Process for image 737
# Process for image 738
# Process for image 739
# Process for image 740
# Process for image 741
# Process for image 742
# Process for image 743
# Process for image 744
# Process for image 745
# Process for image 746
# Process for image 747
# Process for image 748
# Process for image 749
# Process for image 750
# Process for image 751
# Process for image 752
# Process for image 753
# Process for image 754
# Process for image 755
# Process for image 756
# Process for image 757
# Process for image 758
# Process for image 759
# Process for image 760
# Process for image 761
# Process for image 762
# Process for image 763
# Process for image 764
# Process for image 765
# Process for image 766
# Process for image 767
# Process for image 768
# Process for image 769
# Process for image 770
# Process for image 771
# Process for image 772
# Process for image 773
# Process for image 774
# Process for image 775
# Process for image 776
# Process for image 777
# Process for image 778
# Process for image 779
# Process for image 780
# Process for image 781
# Process for image 782
# Process for image 783
# Process for image 784
# Process for image 785
# Process for image 786
# Process for image 787
# Process for image 788
# Process for image 789
# Process for image 790
# Process for image 791
# Process for image 792
# Process for image 793
# Process for image 794
# Process for image 795
# Process for image 796
# Process for image 797
# Process for image 798
# Process for image 799
# Process for image 800
# Process for image 801
# Process for image 802
# Process for image 803
# Process for image 804
# Process for image 805
# Process for image 806
# Process for image 807
# Process for image 808
# Process for image 809
# Process for image 810
# Process for image 811
# Process for image 812
# Process for image 813
# Process for image 814
# Process for image 815
# Process for image 816
# Process for image 817
# Process for image 818
# Process for image 819
# Process for image 820
# Process for image 821
# Process for image 822
# Process for image 823
# Process for image 824
# Process for image 825
# Process for image 826
# Process for image 827
# Process for image 828
# Process for image 829
# Process for image 830
# Process for image 831
# Process for image 832
# Process for image 833
# Process for image 834
# Process for image 835
# Process for image 836
# Process for image 837
# Process for image 838
# Process for image 839
# Process for image 840
# Process for image 841
# Process for image 842
# Process for image 843
# Process for image 844
# Process for image 845
# Process for image 846
# Process for image 847
# Process for image 848
# Process for image 849
# Process for image 850
# Process for image 851
# Process for image 852
# Process for image 853
# Process for image 854
# Process for image 855
# Process for image 856
# Process for image 857
# Process for image 858
# Process for image 859
# Process for image 860
# Process for image 861
# Process for image 862
# Process for image 863
# Process for image 864
# Process for image 865
# Process for image 866
# Process for image 867
# Process for image 868
# Process for image 869
# Process for image 870
# Process for image 871
# Process for image 872
# Process for image 873
# Process for image 874
# Process for image 875
# Process for image 876
# Process for image 877
# Process for image 878
# Process for image 879
# Process for image 880
# Process for image 881
# Process for image 882
# Process for image 883
# Process for image 884
# Process for image 885
# Process for image 886
# Process for image 887
# Process for image 888
# Process for image 889
# Process for image 890
# Process for image 891
# Process for image 892
# Process for image 893
# Process for image 894
# Process for image 895
# Process for image 896
# Process for image 897
# Process for image 898
# Process for image 899
# Process for image 900
# Process for image 901
# Process for image 902
# Process for image 903
# Process for image 904
# Process for image 905
# Process for image 906
# Process for image 907
# Process for image 908
# Process for image 909
# Process for image 910
# Process for image 911
# Process for image 912
# Process for image 913
# Process for image 914
# Process for image 915
# Process for image 916
# Process for image 917
# Process for image 918
# Process for image 919
# Process for image 920
# Process for image 921
# Process for image 922
# Process for image 923
# Process for image 924
# Process for image 925
# Process for image 926
# Process for image 927
# Process for image 928
# Process for image 929
# Process for image 930
# Process for image 931
# Process for image 932
# Process for image 933
# Process for image 934
# Process for image 935
# Process for image 936
# Process for image 937
# Process for image 938
# Process for image 939
# Process for image 940
# Process for image 941
# Process for image 942
# Process for image 943
# Process for image 944
# Process for image 945
# Process for image 946
# Process for image 947
# Process for image 948
# Process for image 949
# Process for image 950
# Process for image 951
# Process for image 952
# Process for image 953
# Process for image 954
# Process for image 955
# Process for image 956
# Process for image 957
# Process for image 958
# Process for image 959
# Process for image 960
# Process for image 961
# Process for image 962
# Process for image 963
# Process for image 964
# Process for image 965
# Process for image 966
# Process for image 967
# Process for image 968
# Process for image 969
# Process for image 970
# Process for image 971
# Process for image 972
# Process for image 973
# Process for image 974
# Process for image 975
# Process for image 976
# Process for image 977
# Process for image 978
# Process for image 979
# Process for image 980
# Process for image 981
# Process for image 982
# Process for image 983
# Process for image 984
# Process for image 985
# Process for image 986
# Process for image 987
# Process for image 988
# Process for image 989
# Process for image 990
# Process for image 991
# Process for image 992
# Process for image 993
# Process for image 994
# Process for image 995
# Process for image 996
# Process for image 997
# Process for image 998
# Process for image 999
# Total time: 19525.974830150604

# %%
new_row = {
    'Framework': ['ezkl-accuracy (pytorch)'],
    'Architecture': ['Input-Dense-Dense (196x25x10)'],
    '# Layers': [3],
    '# Parameters': [5185],
    'Testing Size': [test_size],
    'Accuracy Loss (%)': [loss_/test_size*100],
    'Avg Memory Usage (MB)': [sum(mem_usage_) / len(mem_usage_)],
    'Std Memory Usage': [pd.Series(mem_usage_).std()],
    'Avg Proving Time (s)': [sum(time_cost_) / len(time_cost_)],
    'Std Proving Time': [pd.Series(time_cost_).std()]
}

new_row_df = pd.DataFrame(new_row)

# %%
df = pd.read_csv(csv_path)

df = pd.concat([df, new_row_df], ignore_index=True)
df.to_csv(csv_path, index=False)
df
# Out:
#                     Framework                             Architecture  \
# 0              opml (pytorch)            Input-Dense-Dense (196x25x10)
# 1              opml (pytorch)   Input-Dense-Dense-Dense (196x24x14x10)
# 2              opml (pytorch)            Input-Dense-Dense (784x56x10)
# 3   circomlib-ml (tensorflow)            Input-Dense-Dense (196x25x10)
# 4   circomlib-ml (tensorflow)   Input-Dense-Dense-Dense (196x24x14x10)
# 5   circomlib-ml (tensorflow)            Input-Dense-Dense (784x56x10)
# 6           zkml (tensorflow)            Input-Dense-Dense (196x25x10)
# 7           zkml (tensorflow)   Input-Dense-Dense-Dense (196x24x14x10)
# 8           zkml (tensorflow)            Input-Dense-Dense (784x56x10)
# 9           zkml (tensorflow)  Input-Conv2d-Conv2d-Dense (784x6x16x10)
# 10             ezkl (pytorch)            Input-Dense-Dense (196x25x10)
# 11             ezkl (pytorch)   Input-Dense-Dense-Dense (196x24x14x10)
# 12             ezkl (pytorch)            Input-Dense-Dense (784x56x10)
# 13    ezkl-accuracy (pytorch)            Input-Dense-Dense (196x25x10)
#
#     # Layers  # Parameters  Testing Size  Accuracy Loss (%)  \
# 0          3          5185          5000               3.52
# 1          4          5228          5000               3.42
# 2          3         44543          2500               0.72
# 3          3          5185          2500               0.00
# 4          4          5228          2500               0.88
# 5          3         44543          2500               0.04
# 6          3          5185          1000               0.10
# 7          4          5228          2500               0.00
# 8          3         44543          1000               0.00
# 9          4          5142          1000               0.10
# 10         3          5185         10000               4.11
# 11         4          5228         10000              15.71
# 12         3         44543         10000               4.96
# 13         3          5185          1000               0.00
#
#     Avg Memory Usage (MB)  Std Memory Usage  Avg Proving Time (s)  \
# 0               74.351948          1.419725              0.809440
# 1               74.450789          1.491530              0.829767
# 2               89.120883          2.254392              3.609974
# 3              998.735128          8.040170              1.169482
# 4              315.435559          1.690681              0.452942
# 5             2328.322411         34.436486              2.351284
# 6             2334.295629         12.335301             21.263430
# 7             2338.480847         13.611456             22.168541
# 8             2357.363156         11.750076             22.012543
# 9             1764.619016         12.589448             15.618183
# 10              91.608069          0.756873              0.660479
# 11              91.589901          0.742728              0.693572
# 12             222.911670          3.971043              2.657050
# 13            2636.281324       1081.227782             19.525911
#
#     Std Proving Time
# 0           0.074357
# 1           0.085084
# 2           0.421732
# 3           0.108491
# 4           0.031613
# 5           0.147113
# 6           0.294183
# 7           0.528263
# 8           0.317096
# 9           0.825017
# 10          0.025701
# 11          0.024197
# 12          0.161535
# 13          8.710526

# %% [markdown]
# ## Benchmark for 196_24_14_10 DNN Model

# %%
# After login
arch_folder = "input-dense-dense-dense/"
layers = [196,24,14,10]
model_name = "_".join([str(x) for x in layers])
model_path = "../../models/" + arch_folder + model_name

state_dict = torch.load(model_path + ".pth")

output_folder = './tmp/' + "_".join([str(x) for x in layers]) + "/"
os.makedirs(output_folder, exist_ok=True)

# %%
class Net(nn.Module):
    def __init__(self, num_classes=10):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(layers[0], layers[1])  # Flatten 
        self.fc2 = nn.Linear(layers[1], layers[2]) 
        self.fc3 = nn.Linear(layers[2], layers[3]) 

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
model_pt = Net()
model_pt.load_state_dict(state_dict)
model_pt.eval()  # Set the model to evaluation mode

with torch.no_grad():  # Ensure gradients are not computed
    predictions = model_pt(test_images_pt_downsampled)
    predicted_labels = predictions.argmax(dim=1)

predicted_labels = predicted_labels.tolist()

# %%
# Evaluate the PyTorch model
accuracy = evaluate_pytorch_model(model_pt, test_images_pt_downsampled, test_labels_pt)
print(f'Accuracy of the PyTorch model on the test images: {accuracy:.8f}%')
# Out:
# Accuracy of the PyTorch model on the test images: 95.56000000%

# %% [markdown]
# ### Benchmark - resource

# %%
test_size = 10
loss_, mem_usage_, time_cost_ = benchmark_dnn(test_images_pt_downsampled[:test_size], predicted_labels[:test_size], model_pt)
# Out:
# Process for image 0
# Process for image 1
# Process for image 2
# Process for image 3
# Process for image 4
# Process for image 5
# Process for image 6
# Process for image 7
# Process for image 8
# Process for image 9
# Total time: 7.382734298706055

# %%
new_row = {
    'Framework': ['ezkl-accuracy (pytorch)'],
    'Architecture': ['Input-Dense-Dense (196x24x14x10'],
    '# Layers': [4],
    '# Parameters': [5228],
    'Testing Size': [test_size],
    'Accuracy Loss (%)': [loss_/test_size*100],
    'Avg Memory Usage (MB)': [sum(mem_usage_) / len(mem_usage_)],
    'Std Memory Usage': [pd.Series(mem_usage_).std()],
    'Avg Proving Time (s)': [sum(time_cost_) / len(time_cost_)],
    'Std Proving Time': [pd.Series(time_cost_).std()]
}

new_row_df = pd.DataFrame(new_row)

# %%
df = pd.read_csv(csv_path)

df = pd.concat([df, new_row_df], ignore_index=True)
df.to_csv(csv_path, index=False)
df
# Out:
#                    Framework                           Architecture  # Layers  \
# 0             opml (pytorch)          Input-Dense-Dense (196x25x10)         3
# 1             opml (pytorch)          Input-Dense-Dense (784x56x10)         3
# 2             opml (pytorch)  Input-Dense-Dense-Dense (196x24x14x10         4
# 3  circomlib-ml (tensorflow)          Input-Dense-Dense (196x25x10)         3
# 4  circomlib-ml (tensorflow)           Input-Dense-Dense (784x56x10         3
# 5          zkml (tensorflow)          Input-Dense-Dense (196x25x10)         3
# 6          zkml (tensorflow)          Input-Dense-Dense (784x56x10)         3
# 7          zkml (tensorflow)        Input-Dense-Dense (196x24x14x10         4
# 8             ezkl (pytorch)           Input-Dense-Dense (196x25x10         3
# 9             ezkl (pytorch)        Input-Dense-Dense (196x24x14x10         4
#
#    # Parameters  Testing Size  Accuracy Loss (%)  Avg Memory Usage (MB)  \
# 0          5185          5000               3.52              74.351948
# 1         44543          2500               0.72              89.120883
# 2          5228          5000               3.42              74.450789
# 3          5185          2500               0.00             998.735128
# 4         44543          2500               0.04            2328.322411
# 5          5185          1000               0.10            2334.295629
# 6         44543          1000               0.00            2357.363156
# 7          5228          2500               0.00            2338.480847
# 8          5185         10000               4.11              91.608069
# 9          5228         10000              15.71              91.589901
#
#    Std Memory Usage  Avg Proving Time (s)  Std Proving Time
# 0          1.419725              0.809440          0.074357
# 1          2.254392              3.609974          0.421732
# 2          1.491530              0.829767          0.085084
# 3          8.040170              1.169482          0.108491
# 4         34.436486              2.351284          0.147113
# 5         12.335301             21.263430          0.294183
# 6         11.750076             22.012543          0.317096
# 7         13.611456             22.168541          0.528263
# 8          0.756873              0.660479          0.025701
# 9          0.742728              0.693572          0.024197

# %% [markdown]
# ## Benchmark for 784_56_10 DNN Model

# %%
# After login
arch_folder = "input-dense-dense/"
layers = [784,56,10]
model_name = "_".join([str(x) for x in layers])
model_path = "../../models/" + arch_folder + model_name

state_dict = torch.load(model_path + ".pth")

output_folder = './tmp/' + "_".join([str(x) for x in layers]) + "/"
os.makedirs(output_folder, exist_ok=True)

# %%
class Net(nn.Module):
    def __init__(self, num_classes=10):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(layers[0], layers[1])  # Flatten 
        self.fc2 = nn.Linear(layers[1], layers[2])  

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
    
model_pt = Net()
model_pt.load_state_dict(state_dict)
model_pt.eval()  # Set the model to evaluation mode

with torch.no_grad():  # Ensure gradients are not computed
    predictions = model_pt(test_images_pt)
    predicted_labels = predictions.argmax(dim=1)

predicted_labels = predicted_labels.tolist()

# %%
# Evaluate the PyTorch model
accuracy = evaluate_pytorch_model(model_pt, test_images_pt, test_labels_pt)
print(f'Accuracy of the PyTorch model on the test images: {accuracy:.8f}%')
# Out:
# Accuracy of the PyTorch model on the test images: 97.40000000%

# %% [markdown]
# ### Benchmark

# %%
test_size = 10000
loss_, mem_usage_, time_cost_ = benchmark(test_images_pt[:test_size], predicted_labels[:test_size], model_pt)
# Out:
# Process for image 0
# Process for image 1
# Process for image 2
# Process for image 3
# Process for image 4
# Process for image 5
# Process for image 6
# Process for image 7
# Process for image 8
# Process for image 9
# Process for image 10
# Process for image 11
# Process for image 12
# Process for image 13
# Process for image 14
# Process for image 15
# Process for image 16
# Process for image 17
# Process for image 18
# Loss happens on index 18 predicted_class 2
# Process for image 19
# Process for image 20
# Process for image 21
# Process for image 22
# Process for image 23
# Process for image 24
# Process for image 25
# Process for image 26
# Process for image 27
# Process for image 28
# Process for image 29
# Process for image 30
# Process for image 31
# Process for image 32
# Process for image 33
# Loss happens on index 33 predicted_class 0
# Process for image 34
# Process for image 35
# Process for image 36
# Process for image 37
# Process for image 38
# Process for image 39
# Process for image 40
# Process for image 41
# Process for image 42
# Process for image 43
# Process for image 44
# Process for image 45
# Process for image 46
# Process for image 47
# Process for image 48
# Loss happens on index 48 predicted_class 9
# Process for image 49
# Process for image 50
# Process for image 51
# Process for image 52
# Process for image 53
# Process for image 54
# Process for image 55
# Process for image 56
# Process for image 57
# Process for image 58
# Process for image 59
# Process for image 60
# Process for image 61
# Loss happens on index 61 predicted_class 2
# Process for image 62
# Process for image 63
# Loss happens on index 63 predicted_class 2
# Process for image 64
# Process for image 65
# Process for image 66
# Process for image 67
# Process for image 68
# Process for image 69
# Process for image 70
# Process for image 71
# Process for image 72
# Process for image 73
# Process for image 74
# Process for image 75
# Process for image 76
# Process for image 77
# Process for image 78
# Process for image 79
# Process for image 80
# Process for image 81
# Process for image 82
# Process for image 83
# Process for image 84
# Process for image 85
# Process for image 86
# Process for image 87
# Process for image 88
# Process for image 89
# Process for image 90
# Process for image 91
# Process for image 92
# Process for image 93
# Process for image 94
# Process for image 95
# Process for image 96
# Process for image 97
# Process for image 98
# Process for image 99
# Process for image 100
# Process for image 101
# Process for image 102
# Process for image 103
# Process for image 104
# Process for image 105
# Process for image 106
# Process for image 107
# Process for image 108
# Process for image 109
# Process for image 110
# Process for image 111
# Process for image 112
# Process for image 113
# Process for image 114
# Process for image 115
# Loss happens on index 115 predicted_class 9
# Process for image 116
# Process for image 117
# Process for image 118
# Process for image 119
# Process for image 120
# Process for image 121
# Process for image 122
# Process for image 123
# Process for image 124
# Process for image 125
# Process for image 126
# Loss happens on index 126 predicted_class 5
# Process for image 127
# Process for image 128
# Process for image 129
# Process for image 130
# Process for image 131
# Process for image 132
# Process for image 133
# Process for image 134
# Process for image 135
# Process for image 136
# Process for image 137
# Process for image 138
# Process for image 139
# Process for image 140
# Process for image 141
# Process for image 142
# Process for image 143
# Process for image 144
# Process for image 145
# Process for image 146
# Process for image 147
# Process for image 148
# Process for image 149
# Process for image 150
# Process for image 151
# Process for image 152
# Process for image 153
# Process for image 154
# Process for image 155
# Process for image 156
# Process for image 157
# Process for image 158
# Loss happens on index 158 predicted_class 2
# Process for image 159
# Process for image 160
# Process for image 161
# Process for image 162
# Process for image 163
# Process for image 164
# Process for image 165
# Process for image 166
# Process for image 167
# Process for image 168
# Process for image 169
# Process for image 170
# Process for image 171
# Process for image 172
# Process for image 173
# Process for image 174
# Process for image 175
# Process for image 176
# Process for image 177
# Process for image 178
# Process for image 179
# Loss happens on index 179 predicted_class 2
# Process for image 180
# Process for image 181
# Process for image 182
# Process for image 183
# Process for image 184
# Process for image 185
# Process for image 186
# Process for image 187
# Process for image 188
# Process for image 189
# Process for image 190
# Process for image 191
# Process for image 192
# Process for image 193
# Process for image 194
# Process for image 195
# Process for image 196
# Process for image 197
# Process for image 198
# Process for image 199
# Process for image 200
# Process for image 201
# Process for image 202
# Process for image 203
# Process for image 204
# Process for image 205
# Process for image 206
# Process for image 207
# Process for image 208
# Process for image 209
# Process for image 210
# Process for image 211
# Process for image 212
# Process for image 213
# Process for image 214
# Process for image 215
# Process for image 216
# Process for image 217
# Process for image 218
# Process for image 219
# Process for image 220
# Process for image 221
# Process for image 222
# Process for image 223
# Process for image 224
# Process for image 225
# Process for image 226
# Process for image 227
# Process for image 228
# Process for image 229
# Process for image 230
# Process for image 231
# Process for image 232
# Loss happens on index 232 predicted_class 6
# Process for image 233
# Loss happens on index 233 predicted_class 7
# Process for image 234
# Process for image 235
# Process for image 236
# Process for image 237
# Process for image 238
# Process for image 239
# Process for image 240
# Process for image 241
# Loss happens on index 241 predicted_class 8
# Process for image 242
# Process for image 243
# Process for image 244
# Process for image 245
# Process for image 246
# Process for image 247
# Loss happens on index 247 predicted_class 6
# Process for image 248
# Process for image 249
# Process for image 250
# Process for image 251
# Process for image 252
# Process for image 253
# Process for image 254
# Process for image 255
# Process for image 256
# Process for image 257
# Loss happens on index 257 predicted_class 6
# Process for image 258
# Process for image 259
# Loss happens on index 259 predicted_class 0
# Process for image 260
# Process for image 261
# Process for image 262
# Process for image 263
# Process for image 264
# Process for image 265
# Process for image 266
# Loss happens on index 266 predicted_class 0
# Process for image 267
# Process for image 268
# Process for image 269
# Process for image 270
# Process for image 271
# Process for image 272
# Process for image 273
# Process for image 274
# Process for image 275
# Process for image 276
# Process for image 277
# Process for image 278
# Process for image 279
# Process for image 280
# Process for image 281
# Process for image 282
# Process for image 283
# Process for image 284
# Process for image 285
# Process for image 286
# Process for image 287
# Process for image 288
# Process for image 289
# Process for image 290
# Process for image 291
# Process for image 292
# Process for image 293
# Process for image 294
# Process for image 295
# Process for image 296
# Process for image 297
# Process for image 298
# Process for image 299
# Process for image 300
# Process for image 301
# Process for image 302
# Process for image 303
# Process for image 304
# Process for image 305
# Process for image 306
# Process for image 307
# Process for image 308
# Process for image 309
# Process for image 310
# Process for image 311
# Process for image 312
# Process for image 313
# Loss happens on index 313 predicted_class 5
# Process for image 314
# Process for image 315
# Process for image 316
# Process for image 317
# Process for image 318
# Process for image 319
# Process for image 320
# Process for image 321
# Process for image 322
# Process for image 323
# Process for image 324
# Process for image 325
# Process for image 326
# Process for image 327
# Process for image 328
# Process for image 329
# Process for image 330
# Process for image 331
# Process for image 332
# Process for image 333
# Process for image 334
# Process for image 335
# Loss happens on index 335 predicted_class 2
# Process for image 336
# Process for image 337
# Process for image 338
# Process for image 339
# Process for image 340
# Process for image 341
# Process for image 342
# Process for image 343
# Process for image 344
# Process for image 345
# Process for image 346
# Process for image 347
# Process for image 348
# Process for image 349
# Process for image 350
# Process for image 351
# Process for image 352
# Process for image 353
# Process for image 354
# Process for image 355
# Process for image 356
# Process for image 357
# Process for image 358
# Process for image 359
# Process for image 360
# Process for image 361
# Process for image 362
# Process for image 363
# Process for image 364
# Process for image 365
# Process for image 366
# Loss happens on index 366 predicted_class 2
# Process for image 367
# Process for image 368
# Process for image 369
# Process for image 370
# Process for image 371
# Process for image 372
# Process for image 373
# Process for image 374
# Process for image 375
# Process for image 376
# Loss happens on index 376 predicted_class 9
# Process for image 377
# Process for image 378
# Process for image 379
# Process for image 380
# Process for image 381
# Process for image 382
# Process for image 383
# Process for image 384
# Process for image 385
# Process for image 386
# Process for image 387
# Process for image 388
# Process for image 389
# Process for image 390
# Process for image 391
# Loss happens on index 391 predicted_class 2
# Process for image 392
# Process for image 393
# Process for image 394
# Process for image 395
# Process for image 396
# Process for image 397
# Process for image 398
# Process for image 399
# Loss happens on index 399 predicted_class 2
# Process for image 400
# Process for image 401
# Loss happens on index 401 predicted_class 2
# Process for image 402
# Process for image 403
# Process for image 404
# Process for image 405
# Process for image 406
# Process for image 407
# Process for image 408
# Process for image 409
# Process for image 410
# Process for image 411
# Process for image 412
# Process for image 413
# Process for image 414
# Process for image 415
# Process for image 416
# Process for image 417
# Loss happens on index 417 predicted_class 7
# Process for image 418
# Process for image 419
# Process for image 420
# Process for image 421
# Process for image 422
# Process for image 423
# Process for image 424
# Process for image 425
# Process for image 426
# Process for image 427
# Process for image 428
# Process for image 429
# Process for image 430
# Process for image 431
# Loss happens on index 431 predicted_class 2
# Process for image 432
# Process for image 433
# Process for image 434
# Process for image 435
# Loss happens on index 435 predicted_class 7
# Process for image 436
# Process for image 437
# Process for image 438
# Process for image 439
# Process for image 440
# Process for image 441
# Process for image 442
# Process for image 443
# Process for image 444
# Process for image 445
# Process for image 446
# Process for image 447
# Loss happens on index 447 predicted_class 9
# Process for image 448
# Process for image 449
# Process for image 450
# Process for image 451
# Process for image 452
# Process for image 453
# Process for image 454
# Process for image 455
# Process for image 456
# Process for image 457
# Process for image 458
# Process for image 459
# Process for image 460
# Loss happens on index 460 predicted_class 9
# Process for image 461
# Process for image 462
# Process for image 463
# Process for image 464
# Process for image 465
# Process for image 466
# Process for image 467
# Process for image 468
# Process for image 469
# Process for image 470
# Loss happens on index 470 predicted_class 2
# Process for image 471
# Process for image 472
# Process for image 473
# Process for image 474
# Process for image 475
# Process for image 476
# Process for image 477
# Process for image 478
# Loss happens on index 478 predicted_class 6
# Process for image 479
# Process for image 480
# Process for image 481
# Process for image 482
# Process for image 483
# Process for image 484
# Process for image 485
# Process for image 486
# Process for image 487
# Process for image 488
# Process for image 489
# Process for image 490
# Process for image 491
# Process for image 492
# Process for image 493
# Process for image 494
# Process for image 495
# Loss happens on index 495 predicted_class 2
# Process for image 496
# Process for image 497
# Process for image 498
# Process for image 499
# Process for image 500
# Process for image 501
# Process for image 502
# Process for image 503
# Process for image 504
# Process for image 505
# Process for image 506
# Process for image 507
# Process for image 508
# Process for image 509
# Process for image 510
# Process for image 511
# Process for image 512
# Process for image 513
# Process for image 514
# Process for image 515
# Process for image 516
# Process for image 517
# Process for image 518
# Process for image 519
# Process for image 520
# Process for image 521
# Process for image 522
# Process for image 523
# Process for image 524
# Process for image 525
# Process for image 526
# Process for image 527
# Process for image 528
# Loss happens on index 528 predicted_class 2
# Process for image 529
# Process for image 530
# Process for image 531
# Process for image 532
# Process for image 533
# Process for image 534
# Process for image 535
# Process for image 536
# Process for image 537
# Process for image 538
# Process for image 539
# Process for image 540
# Process for image 541
# Process for image 542
# Loss happens on index 542 predicted_class 2
# Process for image 543
# Loss happens on index 543 predicted_class 6
# Process for image 544
# Process for image 545
# Process for image 546
# Process for image 547
# Process for image 548
# Process for image 549
# Process for image 550
# Process for image 551
# Process for image 552
# Process for image 553
# Loss happens on index 553 predicted_class 6
# Process for image 554
# Process for image 555
# Loss happens on index 555 predicted_class 2
# Process for image 556
# Process for image 557
# Process for image 558
# Process for image 559
# Process for image 560
# Process for image 561
# Process for image 562
# Process for image 563
# Process for image 564
# Process for image 565
# Loss happens on index 565 predicted_class 9
# Process for image 566
# Process for image 567
# Process for image 568
# Process for image 569
# Process for image 570
# Process for image 571
# Loss happens on index 571 predicted_class 9
# Process for image 572
# Process for image 573
# Process for image 574
# Process for image 575
# Process for image 576
# Process for image 577
# Process for image 578
# Loss happens on index 578 predicted_class 2
# Process for image 579
# Process for image 580
# Process for image 581
# Process for image 582
# Process for image 583
# Process for image 584
# Process for image 585
# Process for image 586
# Process for image 587
# Process for image 588
# Process for image 589
# Process for image 590
# Process for image 591
# Process for image 592
# Process for image 593
# Process for image 594
# Process for image 595
# Process for image 596
# Loss happens on index 596 predicted_class 2
# Process for image 597
# Process for image 598
# Process for image 599
# Process for image 600
# Process for image 601
# Process for image 602
# Process for image 603
# Process for image 604
# Process for image 605
# Process for image 606
# Loss happens on index 606 predicted_class 3
# Process for image 607
# Process for image 608
# Process for image 609
# Process for image 610
# Loss happens on index 610 predicted_class 6
# Process for image 611
# Process for image 612
# Process for image 613
# Loss happens on index 613 predicted_class 2
# Process for image 614
# Process for image 615
# Process for image 616
# Process for image 617
# Process for image 618
# Process for image 619
# Loss happens on index 619 predicted_class 2
# Process for image 620
# Process for image 621
# Process for image 622
# Process for image 623
# Process for image 624
# Process for image 625
# Process for image 626
# Process for image 627
# Loss happens on index 627 predicted_class 7
# Process for image 628
# Process for image 629
# Process for image 630
# Process for image 631
# Loss happens on index 631 predicted_class 2
# Process for image 632
# Process for image 633
# Process for image 634
# Process for image 635
# Process for image 636
# Process for image 637
# Process for image 638
# Process for image 639
# Process for image 640
# Process for image 641
# Loss happens on index 641 predicted_class 2
# Process for image 642
# Process for image 643
# Process for image 644
# Process for image 645
# Process for image 646
# Process for image 647
# Process for image 648
# Process for image 649
# Process for image 650
# Process for image 651
# Process for image 652
# Process for image 653
# Process for image 654
# Process for image 655
# Process for image 656
# Process for image 657
# Process for image 658
# Process for image 659
# Loss happens on index 659 predicted_class 2
# Process for image 660
# Process for image 661
# Process for image 662
# Process for image 663
# Process for image 664
# Process for image 665
# Process for image 666
# Process for image 667
# Process for image 668
# Process for image 669
# Process for image 670
# Process for image 671
# Process for image 672
# Process for image 673
# Process for image 674
# Process for image 675
# Process for image 676
# Process for image 677
# Process for image 678
# Process for image 679
# Process for image 680
# Process for image 681
# Process for image 682
# Process for image 683
# Process for image 684
# Loss happens on index 684 predicted_class 2
# Process for image 685
# Process for image 686
# Process for image 687
# Process for image 688
# Process for image 689
# Process for image 690
# Process for image 691
# Loss happens on index 691 predicted_class 4
# Process for image 692
# Process for image 693
# Process for image 694
# Process for image 695
# Process for image 696
# Process for image 697
# Process for image 698
# Process for image 699
# Process for image 700
# Process for image 701
# Process for image 702
# Process for image 703
# Process for image 704
# Process for image 705
# Process for image 706
# Process for image 707
# Loss happens on index 707 predicted_class 9
# Process for image 708
# Process for image 709
# Process for image 710
# Process for image 711
# Process for image 712
# Process for image 713
# Process for image 714
# Process for image 715
# Process for image 716
# Process for image 717
# Process for image 718
# Process for image 719
# Process for image 720
# Loss happens on index 720 predicted_class 5
# Process for image 721
# Process for image 722
# Process for image 723
# Process for image 724
# Process for image 725
# Process for image 726
# Process for image 727
# Process for image 728
# Process for image 729
# Process for image 730
# Process for image 731
# Process for image 732
# Process for image 733
# Process for image 734
# Process for image 735
# Process for image 736
# Process for image 737
# Process for image 738
# Process for image 739
# Process for image 740
# Process for image 741
# Process for image 742
# Process for image 743
# Process for image 744
# Process for image 745
# Process for image 746
# Process for image 747
# Process for image 748
# Process for image 749
# Process for image 750
# Process for image 751
# Process for image 752
# Process for image 753
# Process for image 754
# Process for image 755
# Process for image 756
# Process for image 757
# Process for image 758
# Process for image 759
# Process for image 760
# Process for image 761
# Process for image 762
# Process for image 763
# Process for image 764
# Process for image 765
# Process for image 766
# Process for image 767
# Process for image 768
# Process for image 769
# Process for image 770
# Loss happens on index 770 predicted_class 2
# Process for image 771
# Process for image 772
# Process for image 773
# Process for image 774
# Process for image 775
# Process for image 776
# Process for image 777
# Process for image 778
# Process for image 779
# Process for image 780
# Process for image 781
# Process for image 782
# Process for image 783
# Process for image 784
# Process for image 785
# Process for image 786
# Process for image 787
# Process for image 788
# Process for image 789
# Process for image 790
# Process for image 791
# Process for image 792
# Process for image 793
# Process for image 794
# Process for image 795
# Process for image 796
# Process for image 797
# Process for image 798
# Process for image 799
# Process for image 800
# Process for image 801
# Process for image 802
# Process for image 803
# Process for image 804
# Process for image 805
# Process for image 806
# Process for image 807
# Process for image 808
# Process for image 809
# Process for image 810
# Loss happens on index 810 predicted_class 2
# Process for image 811
# Process for image 812
# Process for image 813
# Process for image 814
# Process for image 815
# Process for image 816
# Process for image 817
# Process for image 818
# Process for image 819
# Process for image 820
# Process for image 821
# Process for image 822
# Process for image 823
# Process for image 824
# Process for image 825
# Process for image 826
# Process for image 827
# Process for image 828
# Process for image 829
# Loss happens on index 829 predicted_class 2
# Process for image 830
# Process for image 831
# Process for image 832
# Process for image 833
# Process for image 834
# Process for image 835
# Process for image 836
# Process for image 837
# Process for image 838
# Process for image 839
# Loss happens on index 839 predicted_class 3
# Process for image 840
# Process for image 841
# Process for image 842
# Process for image 843
# Process for image 844
# Process for image 845
# Process for image 846
# Loss happens on index 846 predicted_class 7
# Process for image 847
# Process for image 848
# Process for image 849
# Process for image 850
# Process for image 851
# Process for image 852
# Process for image 853
# Process for image 854
# Process for image 855
# Process for image 856
# Process for image 857
# Process for image 858
# Process for image 859
# Process for image 860
# Process for image 861
# Process for image 862
# Process for image 863
# Process for image 864
# Process for image 865
# Process for image 866
# Process for image 867
# Process for image 868
# Process for image 869
# Process for image 870
# Process for image 871
# Process for image 872
# Process for image 873
# Process for image 874
# Process for image 875
# Process for image 876
# Process for image 877
# Process for image 878
# Process for image 879
# Process for image 880
# Process for image 881
# Process for image 882
# Process for image 883
# Process for image 884
# Process for image 885
# Process for image 886
# Process for image 887
# Process for image 888
# Process for image 889
# Process for image 890
# Loss happens on index 890 predicted_class 3
# Process for image 891
# Process for image 892
# Process for image 893
# Process for image 894
# Process for image 895
# Process for image 896
# Process for image 897
# Process for image 898
# Process for image 899
# Process for image 900
# Process for image 901
# Process for image 902
# Process for image 903
# Process for image 904
# Process for image 905
# Process for image 906
# Process for image 907
# Process for image 908
# Process for image 909
# Process for image 910
# Process for image 911
# Process for image 912
# Process for image 913
# Process for image 914
# Process for image 915
# Process for image 916
# Process for image 917
# Process for image 918
# Process for image 919
# Process for image 920
# Process for image 921
# Process for image 922
# Process for image 923
# Process for image 924
# Process for image 925
# Process for image 926
# Process for image 927
# Process for image 928
# Process for image 929
# Process for image 930
# Process for image 931
# Process for image 932
# Process for image 933
# Process for image 934
# Process for image 935
# Process for image 936
# Process for image 937
# Process for image 938
# Process for image 939
# Process for image 940
# Process for image 941
# Process for image 942
# Process for image 943
# Process for image 944
# Process for image 945
# Process for image 946
# Process for image 947
# Process for image 948
# Process for image 949
# Process for image 950
# Loss happens on index 950 predicted_class 2
# Process for image 951
# Process for image 952
# Process for image 953
# Process for image 954
# Process for image 955
# Process for image 956
# Process for image 957
# Process for image 958
# Process for image 959
# Loss happens on index 959 predicted_class 9
# Process for image 960
# Process for image 961
# Process for image 962
# Process for image 963
# Process for image 964
# Process for image 965
# Process for image 966
# Process for image 967
# Process for image 968
# Process for image 969
# Process for image 970
# Process for image 971
# Process for image 972
# Process for image 973
# Process for image 974
# Process for image 975
# Process for image 976
# Process for image 977
# Process for image 978
# Process for image 979
# Process for image 980
# Process for image 981
# Process for image 982
# Loss happens on index 982 predicted_class 2
# Process for image 983
# Process for image 984
# Process for image 985
# Process for image 986
# Process for image 987
# Process for image 988
# Process for image 989
# Process for image 990
# Process for image 991
# Process for image 992
# Process for image 993
# Process for image 994
# Process for image 995
# Process for image 996
# Process for image 997
# Process for image 998
# Process for image 999
# Process for image 1000
# Process for image 1001
# Process for image 1002
# Process for image 1003
# Process for image 1004
# Process for image 1005
# Process for image 1006
# Process for image 1007
# Process for image 1008
# Process for image 1009
# Process for image 1010
# Process for image 1011
# Process for image 1012
# Process for image 1013
# Process for image 1014
# Loss happens on index 1014 predicted_class 0
# Process for image 1015
# Process for image 1016
# Process for image 1017
# Process for image 1018
# Process for image 1019
# Process for image 1020
# Process for image 1021
# Process for image 1022
# Loss happens on index 1022 predicted_class 9
# Process for image 1023
# Process for image 1024
# Process for image 1025
# Process for image 1026
# Process for image 1027
# Process for image 1028
# Process for image 1029
# Process for image 1030
# Process for image 1031
# Process for image 1032
# Loss happens on index 1032 predicted_class 6
# Process for image 1033
# Process for image 1034
# Process for image 1035
# Process for image 1036
# Process for image 1037
# Process for image 1038
# Process for image 1039
# Loss happens on index 1039 predicted_class 2
# Process for image 1040
# Process for image 1041
# Process for image 1042
# Process for image 1043
# Process for image 1044
# Process for image 1045
# Process for image 1046
# Process for image 1047
# Process for image 1048
# Process for image 1049
# Process for image 1050
# Process for image 1051
# Process for image 1052
# Process for image 1053
# Process for image 1054
# Process for image 1055
# Process for image 1056
# Process for image 1057
# Process for image 1058
# Process for image 1059
# Process for image 1060
# Process for image 1061
# Process for image 1062
# Process for image 1063
# Process for image 1064
# Process for image 1065
# Process for image 1066
# Process for image 1067
# Process for image 1068
# Loss happens on index 1068 predicted_class 4
# Process for image 1069
# Process for image 1070
# Process for image 1071
# Process for image 1072
# Process for image 1073
# Process for image 1074
# Process for image 1075
# Process for image 1076
# Process for image 1077
# Process for image 1078
# Process for image 1079
# Process for image 1080
# Process for image 1081
# Process for image 1082
# Process for image 1083
# Process for image 1084
# Process for image 1085
# Process for image 1086
# Process for image 1087
# Process for image 1088
# Process for image 1089
# Process for image 1090
# Process for image 1091
# Process for image 1092
# Process for image 1093
# Loss happens on index 1093 predicted_class 2
# Process for image 1094
# Process for image 1095
# Process for image 1096
# Loss happens on index 1096 predicted_class 9
# Process for image 1097
# Process for image 1098
# Process for image 1099
# Process for image 1100
# Process for image 1101
# Process for image 1102
# Process for image 1103
# Process for image 1104
# Process for image 1105
# Process for image 1106
# Process for image 1107
# Loss happens on index 1107 predicted_class 5
# Process for image 1108
# Process for image 1109
# Process for image 1110
# Process for image 1111
# Process for image 1112
# Process for image 1113
# Process for image 1114
# Loss happens on index 1114 predicted_class 2
# Process for image 1115
# Process for image 1116
# Process for image 1117
# Process for image 1118
# Loss happens on index 1118 predicted_class 2
# Process for image 1119
# Process for image 1120
# Process for image 1121
# Process for image 1122
# Process for image 1123
# Process for image 1124
# Process for image 1125
# Process for image 1126
# Process for image 1127
# Process for image 1128
# Loss happens on index 1128 predicted_class 2
# Process for image 1129
# Process for image 1130
# Process for image 1131
# Process for image 1132
# Process for image 1133
# Process for image 1134
# Process for image 1135
# Process for image 1136
# Process for image 1137
# Process for image 1138
# Process for image 1139
# Process for image 1140
# Process for image 1141
# Process for image 1142
# Process for image 1143
# Process for image 1144
# Process for image 1145
# Process for image 1146
# Process for image 1147
# Process for image 1148
# Process for image 1149
# Process for image 1150
# Process for image 1151
# Process for image 1152
# Process for image 1153
# Process for image 1154
# Process for image 1155
# Process for image 1156
# Process for image 1157
# Process for image 1158
# Process for image 1159
# Process for image 1160
# Process for image 1161
# Process for image 1162
# Process for image 1163
# Process for image 1164
# Process for image 1165
# Process for image 1166
# Process for image 1167
# Process for image 1168
# Process for image 1169
# Process for image 1170
# Process for image 1171
# Process for image 1172
# Process for image 1173
# Process for image 1174
# Process for image 1175
# Process for image 1176
# Process for image 1177
# Process for image 1178
# Loss happens on index 1178 predicted_class 6
# Process for image 1179
# Process for image 1180
# Process for image 1181
# Loss happens on index 1181 predicted_class 6
# Process for image 1182
# Loss happens on index 1182 predicted_class 6
# Process for image 1183
# Process for image 1184
# Process for image 1185
# Process for image 1186
# Process for image 1187
# Process for image 1188
# Process for image 1189
# Process for image 1190
# Process for image 1191
# Process for image 1192
# Process for image 1193
# Process for image 1194
# Process for image 1195
# Process for image 1196
# Process for image 1197
# Process for image 1198
# Process for image 1199
# Process for image 1200
# Process for image 1201
# Process for image 1202
# Process for image 1203
# Process for image 1204
# Process for image 1205
# Process for image 1206
# Loss happens on index 1206 predicted_class 2
# Process for image 1207
# Process for image 1208
# Process for image 1209
# Process for image 1210
# Process for image 1211
# Process for image 1212
# Process for image 1213
# Process for image 1214
# Process for image 1215
# Process for image 1216
# Process for image 1217
# Process for image 1218
# Process for image 1219
# Process for image 1220
# Process for image 1221
# Process for image 1222
# Process for image 1223
# Process for image 1224
# Process for image 1225
# Process for image 1226
# Process for image 1227
# Process for image 1228
# Process for image 1229
# Loss happens on index 1229 predicted_class 2
# Process for image 1230
# Process for image 1231
# Process for image 1232
# Loss happens on index 1232 predicted_class 6
# Process for image 1233
# Process for image 1234
# Loss happens on index 1234 predicted_class 2
# Process for image 1235
# Process for image 1236
# Process for image 1237
# Process for image 1238
# Process for image 1239
# Process for image 1240
# Process for image 1241
# Process for image 1242
# Process for image 1243
# Process for image 1244
# Process for image 1245
# Process for image 1246
# Process for image 1247
# Process for image 1248
# Process for image 1249
# Process for image 1250
# Process for image 1251
# Process for image 1252
# Process for image 1253
# Process for image 1254
# Process for image 1255
# Process for image 1256
# Process for image 1257
# Process for image 1258
# Process for image 1259
# Process for image 1260
# Process for image 1261
# Process for image 1262
# Process for image 1263
# Process for image 1264
# Process for image 1265
# Process for image 1266
# Process for image 1267
# Process for image 1268
# Process for image 1269
# Process for image 1270
# Process for image 1271
# Process for image 1272
# Process for image 1273
# Process for image 1274
# Process for image 1275
# Process for image 1276
# Process for image 1277
# Process for image 1278
# Process for image 1279
# Process for image 1280
# Process for image 1281
# Process for image 1282
# Process for image 1283
# Loss happens on index 1283 predicted_class 2
# Process for image 1284
# Process for image 1285
# Process for image 1286
# Process for image 1287
# Process for image 1288
# Process for image 1289
# Loss happens on index 1289 predicted_class 9
# Process for image 1290
# Process for image 1291
# Process for image 1292
# Process for image 1293
# Process for image 1294
# Process for image 1295
# Process for image 1296
# Process for image 1297
# Process for image 1298
# Process for image 1299
# Process for image 1300
# Process for image 1301
# Process for image 1302
# Process for image 1303
# Process for image 1304
# Process for image 1305
# Process for image 1306
# Process for image 1307
# Process for image 1308
# Process for image 1309
# Process for image 1310
# Loss happens on index 1310 predicted_class 7
# Process for image 1311
# Process for image 1312
# Loss happens on index 1312 predicted_class 2
# Process for image 1313
# Process for image 1314
# Process for image 1315
# Process for image 1316
# Process for image 1317
# Process for image 1318
# Process for image 1319
# Loss happens on index 1319 predicted_class 0
# Process for image 1320
# Loss happens on index 1320 predicted_class 1
# Process for image 1321
# Process for image 1322
# Process for image 1323
# Process for image 1324
# Loss happens on index 1324 predicted_class 2
# Process for image 1325
# Loss happens on index 1325 predicted_class 6
# Process for image 1326
# Process for image 1327
# Process for image 1328
# Process for image 1329
# Process for image 1330
# Process for image 1331
# Process for image 1332
# Process for image 1333
# Process for image 1334
# Process for image 1335
# Process for image 1336
# Process for image 1337
# Process for image 1338
# Process for image 1339
# Process for image 1340
# Process for image 1341
# Process for image 1342
# Process for image 1343
# Process for image 1344
# Process for image 1345
# Process for image 1346
# Process for image 1347
# Process for image 1348
# Process for image 1349
# Process for image 1350
# Process for image 1351
# Process for image 1352
# Process for image 1353
# Process for image 1354
# Process for image 1355
# Process for image 1356
# Process for image 1357
# Process for image 1358
# Process for image 1359
# Process for image 1360
# Process for image 1361
# Process for image 1362
# Process for image 1363
# Process for image 1364
# Process for image 1365
# Process for image 1366
# Process for image 1367
# Process for image 1368
# Process for image 1369
# Process for image 1370
# Process for image 1371
# Process for image 1372
# Process for image 1373
# Process for image 1374
# Process for image 1375
# Process for image 1376
# Process for image 1377
# Process for image 1378
# Process for image 1379
# Process for image 1380
# Process for image 1381
# Process for image 1382
# Process for image 1383
# Process for image 1384
# Process for image 1385
# Process for image 1386
# Process for image 1387
# Process for image 1388
# Process for image 1389
# Process for image 1390
# Process for image 1391
# Process for image 1392
# Process for image 1393
# Process for image 1394
# Process for image 1395
# Process for image 1396
# Process for image 1397
# Process for image 1398
# Process for image 1399
# Process for image 1400
# Process for image 1401
# Process for image 1402
# Process for image 1403
# Process for image 1404
# Process for image 1405
# Process for image 1406
# Process for image 1407
# Process for image 1408
# Process for image 1409
# Process for image 1410
# Process for image 1411
# Process for image 1412
# Process for image 1413
# Process for image 1414
# Process for image 1415
# Loss happens on index 1415 predicted_class 6
# Process for image 1416
# Process for image 1417
# Process for image 1418
# Process for image 1419
# Process for image 1420
# Process for image 1421
# Process for image 1422
# Process for image 1423
# Process for image 1424
# Process for image 1425
# Process for image 1426
# Process for image 1427
# Process for image 1428
# Process for image 1429
# Process for image 1430
# Process for image 1431
# Process for image 1432
# Process for image 1433
# Process for image 1434
# Process for image 1435
# Process for image 1436
# Process for image 1437
# Process for image 1438
# Process for image 1439
# Process for image 1440
# Loss happens on index 1440 predicted_class 2
# Process for image 1441
# Loss happens on index 1441 predicted_class 2
# Process for image 1442
# Process for image 1443
# Process for image 1444
# Process for image 1445
# Process for image 1446
# Process for image 1447
# Process for image 1448
# Process for image 1449
# Process for image 1450
# Process for image 1451
# Process for image 1452
# Process for image 1453
# Process for image 1454
# Process for image 1455
# Process for image 1456
# Process for image 1457
# Process for image 1458
# Process for image 1459
# Process for image 1460
# Process for image 1461
# Process for image 1462
# Process for image 1463
# Process for image 1464
# Process for image 1465
# Process for image 1466
# Process for image 1467
# Process for image 1468
# Process for image 1469
# Process for image 1470
# Process for image 1471
# Process for image 1472
# Process for image 1473
# Process for image 1474
# Process for image 1475
# Process for image 1476
# Process for image 1477
# Process for image 1478
# Process for image 1479
# Process for image 1480
# Process for image 1481
# Process for image 1482
# Process for image 1483
# Process for image 1484
# Process for image 1485
# Process for image 1486
# Process for image 1487
# Process for image 1488
# Process for image 1489
# Process for image 1490
# Process for image 1491
# Process for image 1492
# Process for image 1493
# Process for image 1494
# Loss happens on index 1494 predicted_class 0
# Process for image 1495
# Process for image 1496
# Process for image 1497
# Process for image 1498
# Process for image 1499
# Process for image 1500
# Process for image 1501
# Process for image 1502
# Loss happens on index 1502 predicted_class 2
# Process for image 1503
# Process for image 1504
# Process for image 1505
# Process for image 1506
# Process for image 1507
# Process for image 1508
# Process for image 1509
# Process for image 1510
# Process for image 1511
# Process for image 1512
# Process for image 1513
# Process for image 1514
# Process for image 1515
# Process for image 1516
# Process for image 1517
# Process for image 1518
# Process for image 1519
# Process for image 1520
# Process for image 1521
# Process for image 1522
# Process for image 1523
# Loss happens on index 1523 predicted_class 6
# Process for image 1524
# Process for image 1525
# Process for image 1526
# Process for image 1527
# Process for image 1528
# Process for image 1529
# Process for image 1530
# Process for image 1531
# Process for image 1532
# Process for image 1533
# Process for image 1534
# Process for image 1535
# Process for image 1536
# Process for image 1537
# Process for image 1538
# Process for image 1539
# Process for image 1540
# Process for image 1541
# Process for image 1542
# Process for image 1543
# Process for image 1544
# Process for image 1545
# Process for image 1546
# Process for image 1547
# Process for image 1548
# Process for image 1549
# Process for image 1550
# Process for image 1551
# Process for image 1552
# Process for image 1553
# Process for image 1554
# Process for image 1555
# Process for image 1556
# Process for image 1557
# Process for image 1558
# Process for image 1559
# Process for image 1560
# Process for image 1561
# Process for image 1562
# Process for image 1563
# Process for image 1564
# Process for image 1565
# Process for image 1566
# Process for image 1567
# Process for image 1568
# Process for image 1569
# Process for image 1570
# Process for image 1571
# Loss happens on index 1571 predicted_class 9
# Process for image 1572
# Loss happens on index 1572 predicted_class 2
# Process for image 1573
# Loss happens on index 1573 predicted_class 2
# Process for image 1574
# Process for image 1575
# Process for image 1576
# Process for image 1577
# Process for image 1578
# Process for image 1579
# Process for image 1580
# Process for image 1581
# Process for image 1582
# Process for image 1583
# Process for image 1584
# Process for image 1585
# Process for image 1586
# Process for image 1587
# Process for image 1588
# Process for image 1589
# Process for image 1590
# Process for image 1591
# Process for image 1592
# Process for image 1593
# Process for image 1594
# Process for image 1595
# Process for image 1596
# Process for image 1597
# Process for image 1598
# Process for image 1599
# Process for image 1600
# Process for image 1601
# Loss happens on index 1601 predicted_class 2
# Process for image 1602
# Process for image 1603
# Process for image 1604
# Process for image 1605
# Process for image 1606
# Process for image 1607
# Loss happens on index 1607 predicted_class 4
# Process for image 1608
# Process for image 1609
# Process for image 1610
# Process for image 1611
# Process for image 1612
# Process for image 1613
# Process for image 1614
# Process for image 1615
# Process for image 1616
# Process for image 1617
# Process for image 1618
# Process for image 1619
# Process for image 1620
# Process for image 1621
# Loss happens on index 1621 predicted_class 0
# Process for image 1622
# Process for image 1623
# Process for image 1624
# Process for image 1625
# Process for image 1626
# Process for image 1627
# Process for image 1628
# Process for image 1629
# Process for image 1630
# Process for image 1631
# Process for image 1632
# Process for image 1633
# Process for image 1634
# Process for image 1635
# Process for image 1636
# Process for image 1637
# Process for image 1638
# Process for image 1639
# Process for image 1640
# Loss happens on index 1640 predicted_class 4
# Process for image 1641
# Process for image 1642
# Process for image 1643
# Process for image 1644
# Process for image 1645
# Process for image 1646
# Process for image 1647
# Process for image 1648
# Process for image 1649
# Process for image 1650
# Process for image 1651
# Process for image 1652
# Process for image 1653
# Process for image 1654
# Process for image 1655
# Process for image 1656
# Process for image 1657
# Process for image 1658
# Process for image 1659
# Process for image 1660
# Process for image 1661
# Process for image 1662
# Process for image 1663
# Process for image 1664
# Process for image 1665
# Process for image 1666
# Process for image 1667
# Process for image 1668
# Process for image 1669
# Process for image 1670
# Process for image 1671
# Process for image 1672
# Process for image 1673
# Process for image 1674
# Process for image 1675
# Loss happens on index 1675 predicted_class 2
# Process for image 1676
# Process for image 1677
# Process for image 1678
# Process for image 1679
# Process for image 1680
# Process for image 1681
# Process for image 1682
# Process for image 1683
# Process for image 1684
# Process for image 1685
# Process for image 1686
# Loss happens on index 1686 predicted_class 6
# Process for image 1687
# Process for image 1688
# Process for image 1689
# Process for image 1690
# Process for image 1691
# Process for image 1692
# Process for image 1693
# Process for image 1694
# Loss happens on index 1694 predicted_class 2
# Process for image 1695
# Process for image 1696
# Process for image 1697
# Process for image 1698
# Process for image 1699
# Process for image 1700
# Process for image 1701
# Loss happens on index 1701 predicted_class 9
# Process for image 1702
# Loss happens on index 1702 predicted_class 2
# Process for image 1703
# Process for image 1704
# Process for image 1705
# Process for image 1706
# Process for image 1707
# Process for image 1708
# Process for image 1709
# Process for image 1710
# Process for image 1711
# Process for image 1712
# Process for image 1713
# Process for image 1714
# Process for image 1715
# Process for image 1716
# Process for image 1717
# Process for image 1718
# Process for image 1719
# Process for image 1720
# Process for image 1721
# Process for image 1722
# Process for image 1723
# Process for image 1724
# Process for image 1725
# Process for image 1726
# Process for image 1727
# Process for image 1728
# Process for image 1729
# Process for image 1730
# Process for image 1731
# Process for image 1732
# Loss happens on index 1732 predicted_class 0
# Process for image 1733
# Process for image 1734
# Process for image 1735
# Process for image 1736
# Process for image 1737
# Process for image 1738
# Process for image 1739
# Process for image 1740
# Process for image 1741
# Process for image 1742
# Process for image 1743
# Process for image 1744
# Process for image 1745
# Process for image 1746
# Process for image 1747
# Process for image 1748
# Process for image 1749
# Process for image 1750
# Process for image 1751
# Process for image 1752
# Process for image 1753
# Process for image 1754
# Process for image 1755
# Process for image 1756
# Process for image 1757
# Process for image 1758
# Process for image 1759
# Process for image 1760
# Process for image 1761
# Process for image 1762
# Process for image 1763
# Process for image 1764
# Process for image 1765
# Process for image 1766
# Process for image 1767
# Process for image 1768
# Process for image 1769
# Loss happens on index 1769 predicted_class 2
# Process for image 1770
# Process for image 1771
# Process for image 1772
# Process for image 1773
# Loss happens on index 1773 predicted_class 6
# Process for image 1774
# Process for image 1775
# Process for image 1776
# Process for image 1777
# Process for image 1778
# Process for image 1779
# Loss happens on index 1779 predicted_class 2
# Process for image 1780
# Process for image 1781
# Process for image 1782
# Process for image 1783
# Process for image 1784
# Process for image 1785
# Process for image 1786
# Process for image 1787
# Process for image 1788
# Process for image 1789
# Process for image 1790
# Process for image 1791
# Process for image 1792
# Process for image 1793
# Process for image 1794
# Process for image 1795
# Process for image 1796
# Process for image 1797
# Process for image 1798
# Process for image 1799
# Process for image 1800
# Process for image 1801
# Process for image 1802
# Process for image 1803
# Process for image 1804
# Process for image 1805
# Process for image 1806
# Process for image 1807
# Process for image 1808
# Process for image 1809
# Process for image 1810
# Process for image 1811
# Process for image 1812
# Process for image 1813
# Loss happens on index 1813 predicted_class 3
# Process for image 1814
# Process for image 1815
# Process for image 1816
# Process for image 1817
# Process for image 1818
# Process for image 1819
# Process for image 1820
# Process for image 1821
# Process for image 1822
# Process for image 1823
# Loss happens on index 1823 predicted_class 6
# Process for image 1824
# Process for image 1825
# Process for image 1826
# Process for image 1827
# Process for image 1828
# Loss happens on index 1828 predicted_class 0
# Process for image 1829
# Process for image 1830
# Process for image 1831
# Process for image 1832
# Process for image 1833
# Process for image 1834
# Process for image 1835
# Process for image 1836
# Process for image 1837
# Process for image 1838
# Process for image 1839
# Process for image 1840
# Process for image 1841
# Process for image 1842
# Process for image 1843
# Process for image 1844
# Process for image 1845
# Process for image 1846
# Process for image 1847
# Process for image 1848
# Process for image 1849
# Process for image 1850
# Loss happens on index 1850 predicted_class 2
# Process for image 1851
# Process for image 1852
# Process for image 1853
# Process for image 1854
# Process for image 1855
# Loss happens on index 1855 predicted_class 2
# Process for image 1856
# Process for image 1857
# Process for image 1858
# Process for image 1859
# Process for image 1860
# Process for image 1861
# Process for image 1862
# Process for image 1863
# Process for image 1864
# Process for image 1865
# Process for image 1866
# Process for image 1867
# Process for image 1868
# Process for image 1869
# Process for image 1870
# Process for image 1871
# Process for image 1872
# Process for image 1873
# Process for image 1874
# Process for image 1875
# Process for image 1876
# Process for image 1877
# Process for image 1878
# Loss happens on index 1878 predicted_class 2
# Process for image 1879
# Process for image 1880
# Process for image 1881
# Process for image 1882
# Process for image 1883
# Process for image 1884
# Process for image 1885
# Process for image 1886
# Process for image 1887
# Process for image 1888
# Process for image 1889
# Process for image 1890
# Process for image 1891
# Process for image 1892
# Process for image 1893
# Process for image 1894
# Process for image 1895
# Process for image 1896
# Process for image 1897
# Process for image 1898
# Process for image 1899
# Process for image 1900
# Process for image 1901
# Process for image 1902
# Process for image 1903
# Process for image 1904
# Process for image 1905
# Process for image 1906
# Process for image 1907
# Process for image 1908
# Process for image 1909
# Process for image 1910
# Process for image 1911
# ...
# Process for image 9390
# Process for image 9391
# Process for image 9392
# Process for image 9393
# Process for image 9394
# Process for image 9395
# Process for image 9396
# Process for image 9397
# Process for image 9398
# Process for image 9399
# Process for image 9400
# Process for image 9401
# Process for image 9402
# Process for image 9403
# Process for image 9404
# Process for image 9405
# Process for image 9406
# Process for image 9407
# Process for image 9408
# Process for image 9409
# Process for image 9410
# Process for image 9411
# Process for image 9412
# Process for image 9413
# Process for image 9414
# Process for image 9415
# Process for image 9416
# Process for image 9417
# Process for image 9418
# Loss happens on index 9418 predicted_class 2
# Process for image 9419
# Process for image 9420
# Process for image 9421
# Process for image 9422
# Loss happens on index 9422 predicted_class 5
# Process for image 9423
# Process for image 9424
# Process for image 9425
# Process for image 9426
# Process for image 9427
# Loss happens on index 9427 predicted_class 3
# Process for image 9428
# Process for image 9429
# Process for image 9430
# Process for image 9431
# Process for image 9432
# Process for image 9433
# Process for image 9434
# Process for image 9435
# Process for image 9436
# Process for image 9437
# Process for image 9438
# Process for image 9439
# Process for image 9440
# Process for image 9441
# Process for image 9442
# Process for image 9443
# Process for image 9444
# Process for image 9445
# Process for image 9446
# Process for image 9447
# Process for image 9448
# Process for image 9449
# Process for image 9450
# Process for image 9451
# Process for image 9452
# Process for image 9453
# Process for image 9454
# Process for image 9455
# Process for image 9456
# Process for image 9457
# Process for image 9458
# Process for image 9459
# Process for image 9460
# Process for image 9461
# Process for image 9462
# Process for image 9463
# Process for image 9464
# Process for image 9465
# Process for image 9466
# Process for image 9467
# Process for image 9468
# Process for image 9469
# Process for image 9470
# Process for image 9471
# Process for image 9472
# Process for image 9473
# Process for image 9474
# Process for image 9475
# Process for image 9476
# Process for image 9477
# Process for image 9478
# Process for image 9479
# Process for image 9480
# Process for image 9481
# Process for image 9482
# Process for image 9483
# Process for image 9484
# Process for image 9485
# Process for image 9486
# Process for image 9487
# Process for image 9488
# Process for image 9489
# Process for image 9490
# Process for image 9491
# Process for image 9492
# Process for image 9493
# Process for image 9494
# Process for image 9495
# Process for image 9496
# Process for image 9497
# Process for image 9498
# Process for image 9499
# Process for image 9500
# Process for image 9501
# Process for image 9502
# Process for image 9503
# Process for image 9504
# Process for image 9505
# Loss happens on index 9505 predicted_class 2
# Process for image 9506
# Loss happens on index 9506 predicted_class 7
# Process for image 9507
# Process for image 9508
# Process for image 9509
# Process for image 9510
# Process for image 9511
# Process for image 9512
# Process for image 9513
# Process for image 9514
# Process for image 9515
# Process for image 9516
# Process for image 9517
# Process for image 9518
# Process for image 9519
# Process for image 9520
# Process for image 9521
# Process for image 9522
# Process for image 9523
# Process for image 9524
# Process for image 9525
# Process for image 9526
# Process for image 9527
# Process for image 9528
# Process for image 9529
# Process for image 9530
# Process for image 9531
# Process for image 9532
# Process for image 9533
# Process for image 9534
# Process for image 9535
# Process for image 9536
# Process for image 9537
# Loss happens on index 9537 predicted_class 9
# Process for image 9538
# Loss happens on index 9538 predicted_class 9
# Process for image 9539
# Process for image 9540
# Process for image 9541
# Process for image 9542
# Process for image 9543
# Process for image 9544
# Process for image 9545
# Process for image 9546
# Process for image 9547
# Process for image 9548
# Process for image 9549
# Process for image 9550
# Process for image 9551
# Process for image 9552
# Process for image 9553
# Process for image 9554
# Process for image 9555
# Process for image 9556
# Process for image 9557
# Process for image 9558
# Process for image 9559
# Process for image 9560
# Process for image 9561
# Process for image 9562
# Process for image 9563
# Process for image 9564
# Process for image 9565
# Process for image 9566
# Process for image 9567
# Process for image 9568
# Process for image 9569
# Process for image 9570
# Process for image 9571
# Process for image 9572
# Loss happens on index 9572 predicted_class 2
# Process for image 9573
# Process for image 9574
# Process for image 9575
# Process for image 9576
# Process for image 9577
# Process for image 9578
# Process for image 9579
# Process for image 9580
# Process for image 9581
# Process for image 9582
# Process for image 9583
# Process for image 9584
# Process for image 9585
# Process for image 9586
# Process for image 9587
# Process for image 9588
# Process for image 9589
# Process for image 9590
# Process for image 9591
# Process for image 9592
# Process for image 9593
# Process for image 9594
# Process for image 9595
# Process for image 9596
# Process for image 9597
# Process for image 9598
# Process for image 9599
# Process for image 9600
# Process for image 9601
# Process for image 9602
# Process for image 9603
# Process for image 9604
# Process for image 9605
# Process for image 9606
# Process for image 9607
# Process for image 9608
# Process for image 9609
# Process for image 9610
# Process for image 9611
# Process for image 9612
# Process for image 9613
# Process for image 9614
# Process for image 9615
# Process for image 9616
# Process for image 9617
# Process for image 9618
# Process for image 9619
# Process for image 9620
# Process for image 9621
# Process for image 9622
# Process for image 9623
# Process for image 9624
# Process for image 9625
# Loss happens on index 9625 predicted_class 9
# Process for image 9626
# Process for image 9627
# Process for image 9628
# Process for image 9629
# Process for image 9630
# Loss happens on index 9630 predicted_class 2
# Process for image 9631
# Process for image 9632
# Process for image 9633
# Process for image 9634
# Loss happens on index 9634 predicted_class 7
# Process for image 9635
# Process for image 9636
# Process for image 9637
# Process for image 9638
# Process for image 9639
# Process for image 9640
# Process for image 9641
# Process for image 9642
# Loss happens on index 9642 predicted_class 7
# Process for image 9643
# Process for image 9644
# Process for image 9645
# Process for image 9646
# Process for image 9647
# Process for image 9648
# Process for image 9649
# Process for image 9650
# Process for image 9651
# Process for image 9652
# Process for image 9653
# Process for image 9654
# Process for image 9655
# Process for image 9656
# Process for image 9657
# Process for image 9658
# Process for image 9659
# Process for image 9660
# Process for image 9661
# Process for image 9662
# Process for image 9663
# Process for image 9664
# Loss happens on index 9664 predicted_class 2
# Process for image 9665
# Process for image 9666
# Process for image 9667
# Process for image 9668
# Process for image 9669
# Loss happens on index 9669 predicted_class 5
# Process for image 9670
# Process for image 9671
# Process for image 9672
# Loss happens on index 9672 predicted_class 2
# Process for image 9673
# Process for image 9674
# Process for image 9675
# Process for image 9676
# Process for image 9677
# Process for image 9678
# Process for image 9679
# Process for image 9680
# Process for image 9681
# Process for image 9682
# Process for image 9683
# Process for image 9684
# Process for image 9685
# Process for image 9686
# Process for image 9687
# Process for image 9688
# Process for image 9689
# Process for image 9690
# Process for image 9691
# Process for image 9692
# Process for image 9693
# Process for image 9694
# Process for image 9695
# Loss happens on index 9695 predicted_class 3
# Process for image 9696
# Process for image 9697
# Process for image 9698
# Process for image 9699
# Process for image 9700
# Loss happens on index 9700 predicted_class 2
# Process for image 9701
# Process for image 9702
# Process for image 9703
# Process for image 9704
# Process for image 9705
# Process for image 9706
# Process for image 9707
# Process for image 9708
# Process for image 9709
# Process for image 9710
# Process for image 9711
# Process for image 9712
# Loss happens on index 9712 predicted_class 1
# Process for image 9713
# Process for image 9714
# Process for image 9715
# Process for image 9716
# Process for image 9717
# Process for image 9718
# Process for image 9719
# Loss happens on index 9719 predicted_class 0
# Process for image 9720
# Process for image 9721
# Process for image 9722
# Process for image 9723
# Process for image 9724
# Process for image 9725
# Process for image 9726
# Process for image 9727
# Process for image 9728
# Loss happens on index 9728 predicted_class 6
# Process for image 9729
# Process for image 9730
# Process for image 9731
# Process for image 9732
# Loss happens on index 9732 predicted_class 5
# Process for image 9733
# Process for image 9734
# Process for image 9735
# Process for image 9736
# Process for image 9737
# Process for image 9738
# Process for image 9739
# Process for image 9740
# Process for image 9741
# Process for image 9742
# Process for image 9743
# Process for image 9744
# Loss happens on index 9744 predicted_class 1
# Process for image 9745
# Loss happens on index 9745 predicted_class 6
# Process for image 9746
# Process for image 9747
# Process for image 9748
# Process for image 9749
# Process for image 9750
# Process for image 9751
# Process for image 9752
# Process for image 9753
# Process for image 9754
# Process for image 9755
# Process for image 9756
# Process for image 9757
# Process for image 9758
# Process for image 9759
# Process for image 9760
# Process for image 9761
# Process for image 9762
# Process for image 9763
# Process for image 9764
# Loss happens on index 9764 predicted_class 9
# Process for image 9765
# Process for image 9766
# Process for image 9767
# Process for image 9768
# Process for image 9769
# Process for image 9770
# Process for image 9771
# Process for image 9772
# Process for image 9773
# Process for image 9774
# Process for image 9775
# Process for image 9776
# Process for image 9777
# Process for image 9778
# Process for image 9779
# Process for image 9780
# Process for image 9781
# Process for image 9782
# Process for image 9783
# Loss happens on index 9783 predicted_class 2
# Process for image 9784
# Process for image 9785
# Process for image 9786
# Process for image 9787
# Process for image 9788
# Process for image 9789
# Process for image 9790
# Process for image 9791
# Process for image 9792
# Loss happens on index 9792 predicted_class 9
# Process for image 9793
# Process for image 9794
# Process for image 9795
# Process for image 9796
# Process for image 9797
# Process for image 9798
# Process for image 9799
# Process for image 9800
# Process for image 9801
# Process for image 9802
# Process for image 9803
# Process for image 9804
# Process for image 9805
# Process for image 9806
# Process for image 9807
# Process for image 9808
# Process for image 9809
# Process for image 9810
# Process for image 9811
# Loss happens on index 9811 predicted_class 2
# Process for image 9812
# Process for image 9813
# Process for image 9814
# Process for image 9815
# Process for image 9816
# Process for image 9817
# Process for image 9818
# Process for image 9819
# Process for image 9820
# Process for image 9821
# Process for image 9822
# Process for image 9823
# Process for image 9824
# Process for image 9825
# Process for image 9826
# Process for image 9827
# Process for image 9828
# Process for image 9829
# Process for image 9830
# Process for image 9831
# Loss happens on index 9831 predicted_class 1
# Process for image 9832
# Process for image 9833
# Process for image 9834
# Loss happens on index 9834 predicted_class 6
# Process for image 9835
# Loss happens on index 9835 predicted_class 6
# Process for image 9836
# Process for image 9837
# Process for image 9838
# Process for image 9839
# Loss happens on index 9839 predicted_class 2
# Process for image 9840
# Process for image 9841
# Process for image 9842
# Process for image 9843
# Process for image 9844
# Process for image 9845
# Process for image 9846
# Process for image 9847
# Process for image 9848
# Process for image 9849
# Process for image 9850
# Process for image 9851
# Process for image 9852
# Process for image 9853
# Process for image 9854
# Process for image 9855
# Process for image 9856
# Process for image 9857
# Process for image 9858
# Process for image 9859
# Process for image 9860
# Process for image 9861
# Process for image 9862
# Process for image 9863
# Loss happens on index 9863 predicted_class 6
# Process for image 9864
# Process for image 9865
# Process for image 9866
# Process for image 9867
# Process for image 9868
# Process for image 9869
# Process for image 9870
# Process for image 9871
# Process for image 9872
# Process for image 9873
# Process for image 9874
# Process for image 9875
# Process for image 9876
# Process for image 9877
# Process for image 9878
# Process for image 9879
# Process for image 9880
# Process for image 9881
# Process for image 9882
# Process for image 9883
# Process for image 9884
# Process for image 9885
# Process for image 9886
# Process for image 9887
# Process for image 9888
# Process for image 9889
# Process for image 9890
# Process for image 9891
# Process for image 9892
# Loss happens on index 9892 predicted_class 6
# Process for image 9893
# Process for image 9894
# Process for image 9895
# Process for image 9896
# Process for image 9897
# Process for image 9898
# Process for image 9899
# Process for image 9900
# Process for image 9901
# Process for image 9902
# Process for image 9903
# Process for image 9904
# Process for image 9905
# Loss happens on index 9905 predicted_class 7
# Process for image 9906
# Loss happens on index 9906 predicted_class 2
# Process for image 9907
# Process for image 9908
# Process for image 9909
# Process for image 9910
# Process for image 9911
# Process for image 9912
# Process for image 9913
# Process for image 9914
# Process for image 9915
# Process for image 9916
# Process for image 9917
# Process for image 9918
# Process for image 9919
# Process for image 9920
# Process for image 9921
# Process for image 9922
# Loss happens on index 9922 predicted_class 9
# Process for image 9923
# Process for image 9924
# Process for image 9925
# Loss happens on index 9925 predicted_class 2
# Process for image 9926
# Loss happens on index 9926 predicted_class 1
# Process for image 9927
# Process for image 9928
# Process for image 9929
# Process for image 9930
# Process for image 9931
# Process for image 9932
# Process for image 9933
# Process for image 9934
# Process for image 9935
# Process for image 9936
# Loss happens on index 9936 predicted_class 5
# Process for image 9937
# Process for image 9938
# Process for image 9939
# Process for image 9940
# Process for image 9941
# Loss happens on index 9941 predicted_class 6
# Process for image 9942
# Process for image 9943
# Process for image 9944
# Loss happens on index 9944 predicted_class 9
# Process for image 9945
# Process for image 9946
# Process for image 9947
# Process for image 9948
# Process for image 9949
# Process for image 9950
# Process for image 9951
# Process for image 9952
# Process for image 9953
# Process for image 9954
# Process for image 9955
# Process for image 9956
# Process for image 9957
# Process for image 9958
# Process for image 9959
# Loss happens on index 9959 predicted_class 1
# Process for image 9960
# Process for image 9961
# Process for image 9962
# Process for image 9963
# Process for image 9964
# Process for image 9965
# Process for image 9966
# Process for image 9967
# Process for image 9968
# Process for image 9969
# Process for image 9970
# Process for image 9971
# Process for image 9972
# Process for image 9973
# Process for image 9974
# Process for image 9975
# Loss happens on index 9975 predicted_class 2
# Process for image 9976
# Process for image 9977
# Process for image 9978
# Process for image 9979
# Process for image 9980
# Process for image 9981
# Process for image 9982
# Process for image 9983
# Process for image 9984
# Process for image 9985
# Process for image 9986
# Process for image 9987
# Process for image 9988
# Process for image 9989
# Process for image 9990
# Process for image 9991
# Process for image 9992
# Process for image 9993
# Process for image 9994
# Process for image 9995
# Process for image 9996
# Process for image 9997
# Process for image 9998
# Process for image 9999
# Total time: 26570.99108171463

# %%
new_row = {
    'Framework': ['ezkl (pytorch)'],
    'Architecture': ['Input-Dense-Dense (784x56x10)'],
    '# Layers': [3],
    '# Parameters': [44543],
    'Testing Size': [test_size],
    'Accuracy Loss (%)': [loss_/test_size*100],
    'Avg Memory Usage (MB)': [sum(mem_usage_) / len(mem_usage_)],
    'Std Memory Usage': [pd.Series(mem_usage_).std()],
    'Avg Proving Time (s)': [sum(time_cost_) / len(time_cost_)],
    'Std Proving Time': [pd.Series(time_cost_).std()]
}

new_row_df = pd.DataFrame(new_row)

# %%
df = pd.read_csv(csv_path)

df = pd.concat([df, new_row_df], ignore_index=True)
df.to_csv(csv_path, index=False)
df

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                     Framework                            Architecture  \
# 0              opml (pytorch)           Input-Dense-Dense (196x25x10)
# 1              opml (pytorch)           Input-Dense-Dense (784x56x10)
# 2              opml (pytorch)  Input-Dense-Dense-Dense (196x24x14x10)
# 3   circomlib-ml (tensorflow)           Input-Dense-Dense (196x25x10)
# 4   circomlib-ml (tensorflow)            Input-Dense-Dense (784x56x10
# 5           zkml (tensorflow)           Input-Dense-Dense (196x25x10)
# 6           zkml (tensorflow)           Input-Dense-Dense (784x56x10)
# 7           zkml (tensorflow)        Input-Dense-Dense (196x24x14x10)
# 8              ezkl (pytorch)           Input-Dense-Dense (196x25x10)
# 9              ezkl (pytorch)  Input-Dense-Dense-Dense (196x24x14x10)
# 10             ezkl (pytorch)           Input-Dense-Dense (784x56x10)
#
#     # Layers  # Parameters  Testing Size  Accuracy Loss (%)  \
# 0          3          5185          5000               3.52
# 1          3         44543          2500               0.72
# 2          4          5228          5000               3.42
# 3          3          5185          2500               0.00
# 4          3         44543          2500               0.04
# 5          3          5185          1000               0.10
# 6          3         44543          1000               0.00
# 7          4          5228          2500               0.00
# 8          3          5185         10000               4.11
# 9          4          5228         10000              15.71
# 10         3         44543         10000               4.96
#
#     Avg Memory Usage (MB)  Std Memory Usage  Avg Proving Time (s)  \
# 0               74.351948          1.419725              0.809440
# 1               89.120883          2.254392              3.609974
# 2               74.450789          1.491530              0.829767
# 3              998.735128          8.040170              1.169482
# 4             2328.322411         34.436486              2.351284
# 5             2334.295629         12.335301             21.263430
# 6             2357.363156         11.750076             22.012543
# 7             2338.480847         13.611456             22.168541
# 8               91.608069          0.756873              0.660479
# 9               91.589901          0.742728              0.693572
# 10             222.911670          3.971043              2.657050
#
#     Std Proving Time
# 0           0.074357
# 1           0.421732
# 2           0.085084
# 3           0.108491
# 4           0.147113
# 5           0.294183
# 6           0.317096
# 7           0.528263
# 8           0.025701
# 9           0.024197
# 10          0.161535

# %% [markdown]
# # CNN Models

# %%
import numpy as np
import torch

# Load TensorFlow MNIST data
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images_tf = train_images / 255.0
test_images_tf = test_images / 255.0
train_images_tf = train_images_tf.reshape(train_images.shape[0], 28, 28, 1)
test_images_tf = test_images_tf.reshape(test_images.shape[0], 28, 28, 1)

train_images_tf_14 = tf.image.resize(train_images_tf, [14, 14]).numpy()
test_images_tf_14 = tf.image.resize(test_images_tf, [14, 14]).numpy()

# %%
# Convert to PyTorch format [batch_size, channels, height, width]
train_images_pt = torch.tensor(train_images_tf).permute(0, 3, 1, 2).float()
test_images_pt = torch.tensor(test_images_tf).permute(0, 3, 1, 2).float()


train_images_pt_14 =  torch.tensor(test_images_tf_14).permute(0, 3, 1, 2).float()
test_images_pt_14 =  torch.tensor(test_images_tf_14).permute(0, 3, 1, 2).float()

# %% [markdown]
# ## Benchmark for 14_5_11_80_10_3 CNN Model

# %%
# After login
arch_folder = "input-conv2d-conv2d-dense-dense/"
layers = [14,5,11,80,10,3]
model_name = "_".join([str(x) for x in layers])
model_path = "../../models/" + arch_folder + model_name

state_dict = torch.load(model_path + ".pth")

output_folder = './tmp/' + "_".join([str(x) for x in layers]) + "/"
os.makedirs(output_folder, exist_ok=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

layers = [14, 5, 11, 80, 10, 3]
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # Convolutional encoder
        self.conv1 = nn.Conv2d(1, layers[1], layers[-1]) 
        self.conv2 = nn.Conv2d(layers[1], layers[2], layers[-1]) 

        # Fully connected layers / Dense block
        self.fc1 = nn.Linear(11 * 2 * 2, layers[3]) # 256 * 120
        self.fc2 = nn.Linear(layers[3], layers[4])

    def forward(self, x):
        # Convolutional block
        x = F.avg_pool2d(F.relu(self.conv1(x)), (2, 2)) # Convolution -> Sigmoid -> Avg Pool
        x = F.avg_pool2d(F.relu(self.conv2(x)), (2, 2)) # Convolution -> Sigmoid -> Avg Pool

        # TODO: figure out the resize, currently work on batch_size = 1
        batch_size = x.size(0)
        x = x.reshape(x.size(0),layers[2],-1)  # 16 output channels
        x = np.transpose(x, (0,2,1)).reshape(batch_size,-1)
        #x = x.reshape(batch_size,-1)

        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = self.fc2(x)  # No activation function here, will use CrossEntropyLoss later
        return x

model_pt = Net()
model_pt.load_state_dict(state_dict)
model_pt.eval()  # Set the model to evaluation mode

with torch.no_grad():  # Ensure gradients are not computed
    predictions = model_pt(test_images_pt_14)
    predicted_labels = predictions.argmax(dim=1)

predicted_labels = predicted_labels.tolist()

# %%
# Evaluate the PyTorch model
accuracy = evaluate_pytorch_model(model_pt, test_images_pt_14, test_labels_pt)
print(f'Accuracy of the PyTorch model on the test images: {accuracy:.8f}%')
# Out:
# Accuracy of the PyTorch model on the test images: 97.07000000%

# %% [markdown]
# ### Benchmark

# %%
test_size = 10000
loss_, mem_usage_, time_cost_ = benchmark_cnn(test_images_pt_14[:test_size], 
                                          predicted_labels[:test_size], model_pt)
# Out:
# Process for image 0
# Process for image 1
# Process for image 2
# Process for image 3
# Process for image 4
# Process for image 5
# Process for image 6
# Process for image 7
# Process for image 8
# Process for image 9
# Process for image 10
# Process for image 11
# Process for image 12
# Process for image 13
# Process for image 14
# Process for image 15
# Process for image 16
# Process for image 17
# Process for image 18
# Process for image 19
# Process for image 20
# Process for image 21
# Process for image 22
# Process for image 23
# Process for image 24
# Process for image 25
# Process for image 26
# Process for image 27
# Process for image 28
# Process for image 29
# Process for image 30
# Process for image 31
# Process for image 32
# Process for image 33
# Process for image 34
# Process for image 35
# Process for image 36
# Process for image 37
# Process for image 38
# Process for image 39
# Process for image 40
# Process for image 41
# Process for image 42
# Process for image 43
# Process for image 44
# Process for image 45
# Process for image 46
# Process for image 47
# Process for image 48
# Process for image 49
# Process for image 50
# Process for image 51
# Process for image 52
# Process for image 53
# Process for image 54
# Process for image 55
# Process for image 56
# Process for image 57
# Process for image 58
# Process for image 59
# Process for image 60
# Process for image 61
# Process for image 62
# Process for image 63
# Process for image 64
# Process for image 65
# Process for image 66
# Process for image 67
# Process for image 68
# Process for image 69
# Process for image 70
# Process for image 71
# Process for image 72
# Process for image 73
# Process for image 74
# Process for image 75
# Process for image 76
# Process for image 77
# Process for image 78
# Process for image 79
# Process for image 80
# Process for image 81
# Process for image 82
# Process for image 83
# Process for image 84
# Process for image 85
# Process for image 86
# Process for image 87
# Process for image 88
# Process for image 89
# Process for image 90
# Process for image 91
# Process for image 92
# Process for image 93
# Process for image 94
# Process for image 95
# Process for image 96
# Process for image 97
# Process for image 98
# Process for image 99
# Process for image 100
# Process for image 101
# Process for image 102
# Process for image 103
# Process for image 104
# Process for image 105
# Process for image 106
# Process for image 107
# Process for image 108
# Process for image 109
# Process for image 110
# Process for image 111
# Process for image 112
# Process for image 113
# Process for image 114
# Process for image 115
# Process for image 116
# Process for image 117
# Process for image 118
# Process for image 119
# Process for image 120
# Process for image 121
# Process for image 122
# Process for image 123
# Process for image 124
# Process for image 125
# Process for image 126
# Process for image 127
# Process for image 128
# Process for image 129
# Process for image 130
# Process for image 131
# Process for image 132
# Process for image 133
# Process for image 134
# Process for image 135
# Process for image 136
# Process for image 137
# Process for image 138
# Process for image 139
# Process for image 140
# Process for image 141
# Process for image 142
# Process for image 143
# Process for image 144
# Process for image 145
# Process for image 146
# Process for image 147
# Process for image 148
# Process for image 149
# Process for image 150
# Process for image 151
# Process for image 152
# Process for image 153
# Process for image 154
# Process for image 155
# Process for image 156
# Process for image 157
# Process for image 158
# Process for image 159
# Process for image 160
# Process for image 161
# Process for image 162
# Process for image 163
# Process for image 164
# Process for image 165
# Process for image 166
# Process for image 167
# Process for image 168
# Process for image 169
# Process for image 170
# Process for image 171
# Process for image 172
# Process for image 173
# Process for image 174
# Process for image 175
# Process for image 176
# Process for image 177
# Process for image 178
# Process for image 179
# Process for image 180
# Process for image 181
# Process for image 182
# Process for image 183
# Process for image 184
# Process for image 185
# Process for image 186
# Process for image 187
# Process for image 188
# Process for image 189
# Process for image 190
# Process for image 191
# Process for image 192
# Process for image 193
# Process for image 194
# Process for image 195
# Process for image 196
# Process for image 197
# Process for image 198
# Process for image 199
# Process for image 200
# Process for image 201
# Process for image 202
# Process for image 203
# Process for image 204
# Process for image 205
# Process for image 206
# Process for image 207
# Process for image 208
# Process for image 209
# Process for image 210
# Process for image 211
# Process for image 212
# Process for image 213
# Process for image 214
# Process for image 215
# Process for image 216
# Process for image 217
# Process for image 218
# Process for image 219
# Process for image 220
# Process for image 221
# Process for image 222
# Process for image 223
# Process for image 224
# Process for image 225
# Process for image 226
# Process for image 227
# Process for image 228
# Process for image 229
# Process for image 230
# Process for image 231
# Process for image 232
# Process for image 233
# Process for image 234
# Process for image 235
# Process for image 236
# Process for image 237
# Process for image 238
# Process for image 239
# Process for image 240
# Process for image 241
# Process for image 242
# Process for image 243
# Process for image 244
# Process for image 245
# Process for image 246
# Process for image 247
# Process for image 248
# Process for image 249
# Process for image 250
# Process for image 251
# Process for image 252
# Process for image 253
# Process for image 254
# Process for image 255
# Process for image 256
# Process for image 257
# Process for image 258
# Process for image 259
# Process for image 260
# Process for image 261
# Process for image 262
# Process for image 263
# Process for image 264
# Process for image 265
# Process for image 266
# Process for image 267
# Process for image 268
# Process for image 269
# Process for image 270
# Process for image 271
# Process for image 272
# Process for image 273
# Process for image 274
# Process for image 275
# Process for image 276
# Process for image 277
# Process for image 278
# Process for image 279
# Process for image 280
# Process for image 281
# Process for image 282
# Process for image 283
# Process for image 284
# Process for image 285
# Process for image 286
# Process for image 287
# Process for image 288
# Process for image 289
# Process for image 290
# Process for image 291
# Process for image 292
# Process for image 293
# Process for image 294
# Process for image 295
# Process for image 296
# Process for image 297
# Process for image 298
# Process for image 299
# Process for image 300
# Process for image 301
# Process for image 302
# Process for image 303
# Process for image 304
# Process for image 305
# Process for image 306
# Process for image 307
# Process for image 308
# Process for image 309
# Process for image 310
# Process for image 311
# Process for image 312
# Process for image 313
# Process for image 314
# Process for image 315
# Process for image 316
# Process for image 317
# Process for image 318
# Process for image 319
# Process for image 320
# Process for image 321
# Process for image 322
# Process for image 323
# Process for image 324
# Process for image 325
# Process for image 326
# Process for image 327
# Process for image 328
# Process for image 329
# Process for image 330
# Process for image 331
# Process for image 332
# Process for image 333
# Process for image 334
# Process for image 335
# Process for image 336
# Process for image 337
# Process for image 338
# Process for image 339
# Process for image 340
# Process for image 341
# Process for image 342
# Process for image 343
# Process for image 344
# Process for image 345
# Process for image 346
# Process for image 347
# Process for image 348
# Process for image 349
# Process for image 350
# Process for image 351
# Process for image 352
# Process for image 353
# Process for image 354
# Process for image 355
# Process for image 356
# Process for image 357
# Process for image 358
# Process for image 359
# Process for image 360
# Process for image 361
# Process for image 362
# Process for image 363
# Process for image 364
# Process for image 365
# Process for image 366
# Process for image 367
# Process for image 368
# Process for image 369
# Process for image 370
# Process for image 371
# Process for image 372
# Process for image 373
# Process for image 374
# Process for image 375
# Process for image 376
# Process for image 377
# Process for image 378
# Process for image 379
# Process for image 380
# Process for image 381
# Process for image 382
# Process for image 383
# Process for image 384
# Process for image 385
# Process for image 386
# Process for image 387
# Process for image 388
# Process for image 389
# Process for image 390
# Process for image 391
# Process for image 392
# Process for image 393
# Process for image 394
# Process for image 395
# Process for image 396
# Process for image 397
# Process for image 398
# Process for image 399
# Process for image 400
# Process for image 401
# Process for image 402
# Process for image 403
# Process for image 404
# Process for image 405
# Process for image 406
# Process for image 407
# Process for image 408
# Process for image 409
# Process for image 410
# Process for image 411
# Process for image 412
# Process for image 413
# Process for image 414
# Process for image 415
# Process for image 416
# Process for image 417
# Process for image 418
# Process for image 419
# Process for image 420
# Process for image 421
# Process for image 422
# Process for image 423
# Process for image 424
# Process for image 425
# Process for image 426
# Process for image 427
# Process for image 428
# Process for image 429
# Process for image 430
# Process for image 431
# Process for image 432
# Process for image 433
# Process for image 434
# Process for image 435
# Process for image 436
# Process for image 437
# Process for image 438
# Process for image 439
# Process for image 440
# Process for image 441
# Process for image 442
# Process for image 443
# Process for image 444
# Process for image 445
# Process for image 446
# Process for image 447
# Process for image 448
# Process for image 449
# Process for image 450
# Process for image 451
# Process for image 452
# Process for image 453
# Process for image 454
# Process for image 455
# Process for image 456
# Process for image 457
# Process for image 458
# Process for image 459
# Process for image 460
# Process for image 461
# Process for image 462
# Process for image 463
# Process for image 464
# Process for image 465
# Process for image 466
# Process for image 467
# Process for image 468
# Process for image 469
# Process for image 470
# Process for image 471
# Process for image 472
# Process for image 473
# Process for image 474
# Process for image 475
# Process for image 476
# Process for image 477
# Process for image 478
# Process for image 479
# Process for image 480
# Process for image 481
# Process for image 482
# Process for image 483
# Process for image 484
# Process for image 485
# Process for image 486
# Process for image 487
# Process for image 488
# Process for image 489
# Process for image 490
# Process for image 491
# Process for image 492
# Process for image 493
# Process for image 494
# Process for image 495
# Process for image 496
# Process for image 497
# Process for image 498
# Process for image 499
# Process for image 500
# Process for image 501
# Process for image 502
# Process for image 503
# Process for image 504
# Process for image 505
# Process for image 506
# Process for image 507
# Process for image 508
# Process for image 509
# Process for image 510
# Process for image 511
# Process for image 512
# Process for image 513
# Process for image 514
# Process for image 515
# Process for image 516
# Process for image 517
# Process for image 518
# Process for image 519
# Process for image 520
# Process for image 521
# Process for image 522
# Process for image 523
# Process for image 524
# Process for image 525
# Process for image 526
# Process for image 527
# Process for image 528
# Process for image 529
# Process for image 530
# Process for image 531
# Process for image 532
# Process for image 533
# Process for image 534
# Process for image 535
# Process for image 536
# Process for image 537
# Process for image 538
# Process for image 539
# Process for image 540
# Process for image 541
# Process for image 542
# Process for image 543
# Process for image 544
# Process for image 545
# Process for image 546
# Process for image 547
# Process for image 548
# Process for image 549
# Process for image 550
# Process for image 551
# Process for image 552
# Process for image 553
# Process for image 554
# Process for image 555
# Process for image 556
# Process for image 557
# Process for image 558
# Process for image 559
# Process for image 560
# Process for image 561
# Process for image 562
# Process for image 563
# Process for image 564
# Process for image 565
# Process for image 566
# Process for image 567
# Process for image 568
# Process for image 569
# Process for image 570
# Process for image 571
# Process for image 572
# Process for image 573
# Process for image 574
# Process for image 575
# Process for image 576
# Process for image 577
# Process for image 578
# Process for image 579
# Process for image 580
# Process for image 581
# Process for image 582
# Process for image 583
# Process for image 584
# Process for image 585
# Process for image 586
# Process for image 587
# Process for image 588
# Process for image 589
# Process for image 590
# Process for image 591
# Process for image 592
# Process for image 593
# Process for image 594
# Process for image 595
# Process for image 596
# Process for image 597
# Process for image 598
# Process for image 599
# Process for image 600
# Process for image 601
# Process for image 602
# Process for image 603
# Process for image 604
# Process for image 605
# Process for image 606
# Process for image 607
# Process for image 608
# Process for image 609
# Process for image 610
# Process for image 611
# Process for image 612
# Process for image 613
# Process for image 614
# Process for image 615
# Process for image 616
# Process for image 617
# Process for image 618
# Process for image 619
# Process for image 620
# Process for image 621
# Process for image 622
# Process for image 623
# Process for image 624
# Process for image 625
# Process for image 626
# Process for image 627
# Process for image 628
# Process for image 629
# Process for image 630
# Process for image 631
# Process for image 632
# Process for image 633
# Process for image 634
# Process for image 635
# Process for image 636
# Process for image 637
# Process for image 638
# Process for image 639
# Process for image 640
# Process for image 641
# Process for image 642
# Process for image 643
# Process for image 644
# Process for image 645
# Process for image 646
# Process for image 647
# Process for image 648
# Process for image 649
# Process for image 650
# Process for image 651
# Process for image 652
# Process for image 653
# Process for image 654
# Process for image 655
# Process for image 656
# Process for image 657
# Process for image 658
# Process for image 659
# Process for image 660
# Process for image 661
# Process for image 662
# Process for image 663
# Process for image 664
# Process for image 665
# Process for image 666
# Process for image 667
# Process for image 668
# Process for image 669
# Process for image 670
# Process for image 671
# Process for image 672
# Process for image 673
# Process for image 674
# Process for image 675
# Process for image 676
# Process for image 677
# Process for image 678
# Process for image 679
# Process for image 680
# Process for image 681
# Process for image 682
# Process for image 683
# Process for image 684
# Process for image 685
# Process for image 686
# Process for image 687
# Process for image 688
# Process for image 689
# Process for image 690
# Process for image 691
# Process for image 692
# Process for image 693
# Process for image 694
# Process for image 695
# Process for image 696
# Process for image 697
# Process for image 698
# Process for image 699
# Process for image 700
# Process for image 701
# Process for image 702
# Process for image 703
# Process for image 704
# Process for image 705
# Process for image 706
# Process for image 707
# Process for image 708
# Process for image 709
# Process for image 710
# Process for image 711
# Process for image 712
# Process for image 713
# Process for image 714
# Process for image 715
# Process for image 716
# Process for image 717
# Process for image 718
# Process for image 719
# Process for image 720
# Process for image 721
# Process for image 722
# Process for image 723
# Process for image 724
# Process for image 725
# Process for image 726
# Process for image 727
# Process for image 728
# Process for image 729
# Process for image 730
# Process for image 731
# Process for image 732
# Process for image 733
# Process for image 734
# Process for image 735
# Process for image 736
# Process for image 737
# Process for image 738
# Process for image 739
# Process for image 740
# Process for image 741
# Process for image 742
# Process for image 743
# Process for image 744
# Process for image 745
# Process for image 746
# Process for image 747
# Process for image 748
# Process for image 749
# Process for image 750
# Process for image 751
# Process for image 752
# Process for image 753
# Process for image 754
# Process for image 755
# Process for image 756
# Process for image 757
# Process for image 758
# Process for image 759
# Process for image 760
# Process for image 761
# Process for image 762
# Process for image 763
# Process for image 764
# Process for image 765
# Process for image 766
# Process for image 767
# Process for image 768
# Process for image 769
# Process for image 770
# Process for image 771
# Process for image 772
# Process for image 773
# Process for image 774
# Process for image 775
# Process for image 776
# Process for image 777
# Process for image 778
# Process for image 779
# Process for image 780
# Process for image 781
# Process for image 782
# Process for image 783
# Process for image 784
# Process for image 785
# Process for image 786
# Process for image 787
# Process for image 788
# Process for image 789
# Process for image 790
# Process for image 791
# Process for image 792
# Process for image 793
# Process for image 794
# Process for image 795
# Process for image 796
# Process for image 797
# Process for image 798
# Process for image 799
# Process for image 800
# Process for image 801
# Process for image 802
# Process for image 803
# Process for image 804
# Process for image 805
# Process for image 806
# Process for image 807
# Process for image 808
# Process for image 809
# Process for image 810
# Process for image 811
# Process for image 812
# Process for image 813
# Process for image 814
# Process for image 815
# Process for image 816
# Process for image 817
# Process for image 818
# Process for image 819
# Process for image 820
# Process for image 821
# Process for image 822
# Process for image 823
# Process for image 824
# Process for image 825
# Process for image 826
# Process for image 827
# Process for image 828
# Process for image 829
# Process for image 830
# Process for image 831
# Process for image 832
# Process for image 833
# Process for image 834
# Process for image 835
# Process for image 836
# Process for image 837
# Process for image 838
# Process for image 839
# Process for image 840
# Process for image 841
# Process for image 842
# Process for image 843
# Process for image 844
# Process for image 845
# Process for image 846
# Process for image 847
# Process for image 848
# Process for image 849
# Process for image 850
# Process for image 851
# Process for image 852
# Process for image 853
# Process for image 854
# Process for image 855
# Process for image 856
# Process for image 857
# Process for image 858
# Process for image 859
# Process for image 860
# Process for image 861
# Process for image 862
# Process for image 863
# Process for image 864
# Process for image 865
# Process for image 866
# Process for image 867
# Process for image 868
# Process for image 869
# Process for image 870
# Process for image 871
# Process for image 872
# Process for image 873
# Process for image 874
# Process for image 875
# Process for image 876
# Process for image 877
# Process for image 878
# Process for image 879
# Process for image 880
# Process for image 881
# Process for image 882
# Process for image 883
# Process for image 884
# Process for image 885
# Process for image 886
# Process for image 887
# Process for image 888
# Process for image 889
# Process for image 890
# Process for image 891
# Process for image 892
# Process for image 893
# Process for image 894
# Process for image 895
# Process for image 896
# Process for image 897
# Process for image 898
# Process for image 899
# Process for image 900
# Process for image 901
# Process for image 902
# Process for image 903
# Process for image 904
# Process for image 905
# Process for image 906
# Process for image 907
# Process for image 908
# Process for image 909
# Process for image 910
# Process for image 911
# Process for image 912
# Process for image 913
# Process for image 914
# Process for image 915
# Process for image 916
# Process for image 917
# Process for image 918
# Process for image 919
# Process for image 920
# Process for image 921
# Process for image 922
# Process for image 923
# Process for image 924
# Process for image 925
# Process for image 926
# Process for image 927
# Process for image 928
# Process for image 929
# Process for image 930
# Process for image 931
# Process for image 932
# Process for image 933
# Process for image 934
# Process for image 935
# Process for image 936
# Process for image 937
# Process for image 938
# Process for image 939
# Process for image 940
# Process for image 941
# Process for image 942
# Process for image 943
# Process for image 944
# Process for image 945
# Process for image 946
# Process for image 947
# Process for image 948
# Process for image 949
# Process for image 950
# Process for image 951
# Process for image 952
# Process for image 953
# Process for image 954
# Process for image 955
# Process for image 956
# Process for image 957
# Process for image 958
# Process for image 959
# Process for image 960
# Process for image 961
# Process for image 962
# Process for image 963
# Process for image 964
# Process for image 965
# Process for image 966
# Process for image 967
# Process for image 968
# Process for image 969
# Process for image 970
# Process for image 971
# Process for image 972
# Process for image 973
# Process for image 974
# Process for image 975
# Process for image 976
# Process for image 977
# Process for image 978
# Process for image 979
# Process for image 980
# Process for image 981
# Process for image 982
# Process for image 983
# Process for image 984
# Process for image 985
# Process for image 986
# Process for image 987
# Process for image 988
# Process for image 989
# Process for image 990
# Process for image 991
# Process for image 992
# Process for image 993
# Process for image 994
# Process for image 995
# Process for image 996
# Process for image 997
# Process for image 998
# Process for image 999
# Process for image 1000
# Process for image 1001
# Process for image 1002
# Process for image 1003
# Process for image 1004
# Process for image 1005
# Process for image 1006
# Process for image 1007
# Process for image 1008
# Process for image 1009
# Process for image 1010
# Process for image 1011
# Process for image 1012
# Process for image 1013
# Process for image 1014
# Process for image 1015
# Process for image 1016
# Process for image 1017
# Process for image 1018
# Process for image 1019
# Process for image 1020
# Process for image 1021
# Process for image 1022
# Process for image 1023
# Process for image 1024
# Process for image 1025
# Process for image 1026
# Process for image 1027
# Process for image 1028
# Process for image 1029
# Process for image 1030
# Process for image 1031
# Process for image 1032
# Process for image 1033
# Process for image 1034
# Process for image 1035
# Process for image 1036
# Process for image 1037
# Process for image 1038
# Process for image 1039
# Process for image 1040
# Process for image 1041
# Process for image 1042
# Process for image 1043
# Process for image 1044
# Process for image 1045
# Process for image 1046
# Process for image 1047
# Process for image 1048
# Process for image 1049
# Process for image 1050
# Process for image 1051
# Process for image 1052
# Process for image 1053
# Process for image 1054
# Process for image 1055
# Process for image 1056
# Process for image 1057
# Process for image 1058
# Process for image 1059
# Process for image 1060
# Process for image 1061
# Process for image 1062
# Process for image 1063
# Process for image 1064
# Process for image 1065
# Process for image 1066
# Process for image 1067
# Process for image 1068
# Process for image 1069
# Process for image 1070
# Process for image 1071
# Process for image 1072
# Process for image 1073
# Process for image 1074
# Process for image 1075
# Process for image 1076
# Process for image 1077
# Process for image 1078
# Process for image 1079
# Process for image 1080
# Process for image 1081
# Process for image 1082
# Process for image 1083
# Process for image 1084
# Process for image 1085
# Process for image 1086
# Process for image 1087
# Process for image 1088
# Process for image 1089
# Process for image 1090
# Process for image 1091
# Process for image 1092
# Process for image 1093
# Process for image 1094
# Process for image 1095
# Process for image 1096
# Process for image 1097
# Process for image 1098
# Process for image 1099
# Process for image 1100
# Process for image 1101
# Process for image 1102
# Process for image 1103
# Process for image 1104
# Process for image 1105
# Process for image 1106
# Process for image 1107
# Process for image 1108
# Process for image 1109
# Process for image 1110
# Process for image 1111
# Process for image 1112
# Process for image 1113
# Process for image 1114
# Process for image 1115
# Process for image 1116
# Process for image 1117
# Process for image 1118
# Process for image 1119
# Process for image 1120
# Process for image 1121
# Process for image 1122
# Process for image 1123
# Process for image 1124
# Process for image 1125
# Process for image 1126
# Process for image 1127
# Process for image 1128
# Process for image 1129
# Process for image 1130
# Process for image 1131
# Process for image 1132
# Process for image 1133
# Process for image 1134
# Process for image 1135
# Process for image 1136
# Process for image 1137
# Process for image 1138
# Process for image 1139
# Process for image 1140
# Process for image 1141
# Process for image 1142
# Process for image 1143
# Process for image 1144
# Process for image 1145
# Process for image 1146
# Process for image 1147
# Process for image 1148
# Process for image 1149
# Process for image 1150
# Process for image 1151
# Process for image 1152
# Process for image 1153
# Process for image 1154
# Process for image 1155
# Process for image 1156
# Process for image 1157
# Process for image 1158
# Process for image 1159
# Process for image 1160
# Process for image 1161
# Process for image 1162
# Process for image 1163
# Process for image 1164
# Process for image 1165
# Process for image 1166
# Process for image 1167
# Process for image 1168
# Process for image 1169
# Process for image 1170
# Process for image 1171
# Process for image 1172
# Process for image 1173
# Process for image 1174
# Process for image 1175
# Process for image 1176
# Process for image 1177
# Process for image 1178
# Process for image 1179
# Process for image 1180
# Process for image 1181
# Process for image 1182
# Process for image 1183
# Process for image 1184
# Process for image 1185
# Process for image 1186
# Process for image 1187
# Process for image 1188
# Process for image 1189
# Process for image 1190
# Process for image 1191
# Process for image 1192
# Process for image 1193
# Process for image 1194
# Process for image 1195
# Process for image 1196
# Process for image 1197
# Process for image 1198
# Process for image 1199
# Process for image 1200
# Process for image 1201
# Process for image 1202
# Process for image 1203
# Process for image 1204
# Process for image 1205
# Process for image 1206
# Process for image 1207
# Process for image 1208
# Process for image 1209
# Process for image 1210
# Process for image 1211
# Process for image 1212
# Process for image 1213
# Process for image 1214
# Process for image 1215
# Process for image 1216
# Process for image 1217
# Process for image 1218
# Process for image 1219
# Process for image 1220
# Process for image 1221
# Process for image 1222
# Process for image 1223
# Process for image 1224
# Process for image 1225
# Process for image 1226
# Process for image 1227
# Process for image 1228
# Process for image 1229
# Process for image 1230
# Process for image 1231
# Process for image 1232
# Process for image 1233
# Process for image 1234
# Process for image 1235
# Process for image 1236
# Process for image 1237
# Process for image 1238
# Process for image 1239
# Process for image 1240
# Process for image 1241
# Process for image 1242
# Process for image 1243
# Process for image 1244
# Process for image 1245
# Process for image 1246
# Process for image 1247
# Process for image 1248
# Process for image 1249
# Process for image 1250
# Process for image 1251
# Process for image 1252
# Process for image 1253
# Process for image 1254
# Process for image 1255
# Process for image 1256
# Process for image 1257
# Process for image 1258
# Process for image 1259
# Process for image 1260
# Process for image 1261
# Process for image 1262
# Process for image 1263
# Process for image 1264
# Process for image 1265
# Process for image 1266
# Process for image 1267
# Process for image 1268
# Process for image 1269
# Process for image 1270
# Process for image 1271
# Process for image 1272
# Process for image 1273
# Process for image 1274
# Process for image 1275
# Process for image 1276
# Process for image 1277
# Process for image 1278
# Process for image 1279
# Process for image 1280
# Process for image 1281
# Process for image 1282
# Process for image 1283
# Process for image 1284
# Process for image 1285
# Process for image 1286
# Process for image 1287
# Process for image 1288
# Process for image 1289
# Process for image 1290
# Process for image 1291
# Process for image 1292
# Process for image 1293
# Process for image 1294
# Process for image 1295
# Process for image 1296
# Process for image 1297
# Process for image 1298
# Process for image 1299
# Process for image 1300
# Process for image 1301
# Process for image 1302
# Process for image 1303
# Process for image 1304
# Process for image 1305
# Process for image 1306
# Process for image 1307
# Process for image 1308
# Process for image 1309
# Process for image 1310
# Process for image 1311
# Process for image 1312
# Process for image 1313
# Process for image 1314
# Process for image 1315
# Process for image 1316
# Process for image 1317
# Process for image 1318
# Process for image 1319
# Process for image 1320
# Process for image 1321
# Process for image 1322
# Process for image 1323
# Process for image 1324
# Process for image 1325
# Process for image 1326
# Process for image 1327
# Process for image 1328
# Process for image 1329
# Process for image 1330
# Process for image 1331
# Process for image 1332
# Process for image 1333
# Process for image 1334
# Process for image 1335
# Process for image 1336
# Process for image 1337
# Process for image 1338
# Process for image 1339
# Process for image 1340
# Process for image 1341
# Process for image 1342
# Process for image 1343
# Process for image 1344
# Process for image 1345
# Process for image 1346
# Process for image 1347
# Process for image 1348
# Process for image 1349
# Process for image 1350
# Process for image 1351
# Process for image 1352
# Process for image 1353
# Process for image 1354
# Process for image 1355
# Process for image 1356
# Process for image 1357
# Process for image 1358
# Process for image 1359
# Process for image 1360
# Process for image 1361
# Process for image 1362
# Process for image 1363
# Process for image 1364
# Process for image 1365
# Process for image 1366
# Process for image 1367
# Process for image 1368
# Process for image 1369
# Process for image 1370
# Process for image 1371
# Process for image 1372
# Process for image 1373
# Process for image 1374
# Process for image 1375
# Process for image 1376
# Process for image 1377
# Process for image 1378
# Process for image 1379
# Process for image 1380
# Process for image 1381
# Process for image 1382
# Process for image 1383
# Process for image 1384
# Process for image 1385
# Process for image 1386
# Process for image 1387
# Process for image 1388
# Process for image 1389
# Process for image 1390
# Process for image 1391
# Process for image 1392
# Process for image 1393
# Process for image 1394
# Process for image 1395
# Process for image 1396
# Process for image 1397
# Process for image 1398
# Process for image 1399
# Process for image 1400
# Process for image 1401
# Process for image 1402
# Process for image 1403
# Process for image 1404
# Process for image 1405
# Process for image 1406
# Process for image 1407
# Process for image 1408
# Process for image 1409
# Process for image 1410
# Process for image 1411
# Process for image 1412
# Process for image 1413
# Process for image 1414
# Process for image 1415
# Process for image 1416
# Process for image 1417
# Process for image 1418
# Process for image 1419
# Process for image 1420
# Process for image 1421
# Process for image 1422
# Process for image 1423
# Process for image 1424
# Process for image 1425
# Process for image 1426
# Process for image 1427
# Process for image 1428
# Process for image 1429
# Process for image 1430
# Process for image 1431
# Process for image 1432
# Process for image 1433
# Process for image 1434
# Process for image 1435
# Process for image 1436
# Process for image 1437
# Process for image 1438
# Process for image 1439
# Process for image 1440
# Process for image 1441
# Process for image 1442
# Process for image 1443
# Process for image 1444
# Process for image 1445
# Process for image 1446
# Process for image 1447
# Process for image 1448
# Process for image 1449
# Process for image 1450
# Process for image 1451
# Process for image 1452
# Process for image 1453
# Process for image 1454
# Process for image 1455
# Process for image 1456
# Process for image 1457
# Process for image 1458
# Process for image 1459
# Process for image 1460
# Process for image 1461
# Process for image 1462
# Process for image 1463
# Process for image 1464
# Process for image 1465
# Process for image 1466
# Process for image 1467
# Process for image 1468
# Process for image 1469
# Process for image 1470
# Process for image 1471
# Process for image 1472
# Process for image 1473
# Process for image 1474
# Process for image 1475
# Process for image 1476
# Process for image 1477
# Process for image 1478
# Process for image 1479
# Process for image 1480
# Process for image 1481
# Process for image 1482
# Process for image 1483
# Process for image 1484
# Process for image 1485
# Process for image 1486
# Process for image 1487
# Process for image 1488
# Process for image 1489
# Process for image 1490
# Process for image 1491
# Process for image 1492
# Process for image 1493
# Process for image 1494
# Process for image 1495
# Process for image 1496
# Process for image 1497
# Process for image 1498
# Process for image 1499
# Process for image 1500
# Process for image 1501
# Process for image 1502
# Process for image 1503
# Process for image 1504
# Process for image 1505
# Process for image 1506
# Process for image 1507
# Process for image 1508
# Process for image 1509
# Process for image 1510
# Process for image 1511
# Process for image 1512
# Process for image 1513
# Process for image 1514
# Process for image 1515
# Process for image 1516
# Process for image 1517
# Process for image 1518
# Process for image 1519
# Process for image 1520
# Process for image 1521
# Process for image 1522
# Process for image 1523
# Process for image 1524
# Process for image 1525
# Process for image 1526
# Process for image 1527
# Process for image 1528
# Process for image 1529
# Process for image 1530
# Process for image 1531
# Process for image 1532
# Process for image 1533
# Process for image 1534
# Process for image 1535
# Process for image 1536
# Process for image 1537
# Process for image 1538
# Process for image 1539
# Process for image 1540
# Process for image 1541
# Process for image 1542
# Process for image 1543
# Process for image 1544
# Process for image 1545
# Process for image 1546
# Process for image 1547
# Process for image 1548
# Process for image 1549
# Process for image 1550
# Process for image 1551
# Process for image 1552
# Process for image 1553
# Process for image 1554
# Process for image 1555
# Process for image 1556
# Process for image 1557
# Process for image 1558
# Process for image 1559
# Process for image 1560
# Process for image 1561
# Process for image 1562
# Process for image 1563
# Process for image 1564
# Process for image 1565
# Process for image 1566
# Process for image 1567
# Process for image 1568
# Process for image 1569
# Process for image 1570
# Process for image 1571
# Process for image 1572
# Process for image 1573
# Process for image 1574
# Process for image 1575
# Process for image 1576
# Process for image 1577
# Process for image 1578
# Process for image 1579
# Process for image 1580
# Process for image 1581
# Process for image 1582
# Process for image 1583
# Process for image 1584
# Process for image 1585
# Process for image 1586
# Process for image 1587
# Process for image 1588
# Process for image 1589
# Process for image 1590
# Process for image 1591
# Process for image 1592
# Process for image 1593
# Process for image 1594
# Process for image 1595
# Process for image 1596
# Process for image 1597
# Process for image 1598
# Process for image 1599
# Process for image 1600
# Process for image 1601
# Process for image 1602
# Process for image 1603
# Process for image 1604
# Process for image 1605
# Process for image 1606
# Process for image 1607
# Process for image 1608
# Process for image 1609
# Process for image 1610
# Process for image 1611
# Process for image 1612
# Process for image 1613
# Process for image 1614
# Process for image 1615
# Process for image 1616
# Process for image 1617
# Process for image 1618
# Process for image 1619
# Process for image 1620
# Process for image 1621
# Process for image 1622
# Process for image 1623
# Process for image 1624
# Process for image 1625
# Process for image 1626
# Process for image 1627
# Process for image 1628
# Process for image 1629
# Process for image 1630
# Process for image 1631
# Process for image 1632
# Process for image 1633
# Process for image 1634
# Process for image 1635
# Process for image 1636
# Process for image 1637
# Process for image 1638
# Process for image 1639
# Process for image 1640
# Process for image 1641
# Process for image 1642
# Process for image 1643
# Process for image 1644
# Process for image 1645
# Process for image 1646
# Process for image 1647
# Process for image 1648
# Process for image 1649
# Process for image 1650
# Process for image 1651
# Process for image 1652
# Process for image 1653
# Process for image 1654
# Process for image 1655
# Process for image 1656
# Process for image 1657
# Process for image 1658
# Process for image 1659
# Process for image 1660
# Process for image 1661
# Process for image 1662
# Process for image 1663
# Process for image 1664
# Process for image 1665
# Process for image 1666
# Process for image 1667
# Process for image 1668
# Process for image 1669
# Process for image 1670
# Process for image 1671
# Process for image 1672
# Process for image 1673
# Process for image 1674
# Process for image 1675
# Process for image 1676
# Process for image 1677
# Process for image 1678
# Process for image 1679
# Process for image 1680
# Process for image 1681
# Process for image 1682
# Process for image 1683
# Process for image 1684
# Process for image 1685
# Process for image 1686
# Process for image 1687
# Process for image 1688
# Process for image 1689
# Process for image 1690
# Process for image 1691
# Process for image 1692
# Process for image 1693
# Process for image 1694
# Process for image 1695
# Process for image 1696
# Process for image 1697
# Process for image 1698
# Process for image 1699
# Process for image 1700
# Process for image 1701
# Process for image 1702
# Process for image 1703
# Process for image 1704
# Process for image 1705
# Process for image 1706
# Process for image 1707
# Process for image 1708
# Process for image 1709
# Process for image 1710
# Process for image 1711
# Process for image 1712
# Process for image 1713
# Process for image 1714
# Process for image 1715
# Process for image 1716
# Process for image 1717
# Process for image 1718
# Process for image 1719
# Process for image 1720
# Process for image 1721
# Process for image 1722
# Process for image 1723
# Process for image 1724
# Process for image 1725
# Process for image 1726
# Process for image 1727
# Process for image 1728
# Process for image 1729
# Process for image 1730
# Process for image 1731
# Process for image 1732
# Process for image 1733
# Process for image 1734
# Process for image 1735
# Process for image 1736
# Process for image 1737
# Process for image 1738
# Process for image 1739
# Process for image 1740
# Process for image 1741
# Process for image 1742
# Process for image 1743
# Process for image 1744
# Process for image 1745
# Process for image 1746
# Process for image 1747
# Process for image 1748
# Process for image 1749
# Process for image 1750
# Process for image 1751
# Process for image 1752
# Process for image 1753
# Process for image 1754
# Process for image 1755
# Process for image 1756
# Process for image 1757
# Process for image 1758
# Process for image 1759
# Process for image 1760
# Process for image 1761
# Process for image 1762
# Process for image 1763
# Process for image 1764
# Process for image 1765
# Process for image 1766
# Process for image 1767
# Process for image 1768
# Process for image 1769
# Process for image 1770
# Process for image 1771
# Process for image 1772
# Process for image 1773
# Process for image 1774
# Process for image 1775
# Process for image 1776
# Process for image 1777
# Process for image 1778
# Process for image 1779
# Process for image 1780
# Process for image 1781
# Process for image 1782
# Process for image 1783
# Process for image 1784
# Process for image 1785
# Process for image 1786
# Process for image 1787
# Process for image 1788
# Process for image 1789
# Process for image 1790
# Process for image 1791
# Process for image 1792
# Process for image 1793
# Process for image 1794
# Process for image 1795
# Process for image 1796
# Process for image 1797
# Process for image 1798
# Process for image 1799
# Process for image 1800
# Process for image 1801
# Process for image 1802
# Process for image 1803
# Process for image 1804
# Process for image 1805
# Process for image 1806
# Process for image 1807
# Process for image 1808
# Process for image 1809
# Process for image 1810
# Process for image 1811
# Process for image 1812
# Process for image 1813
# Process for image 1814
# Process for image 1815
# Process for image 1816
# Process for image 1817
# Process for image 1818
# Process for image 1819
# Process for image 1820
# Process for image 1821
# Process for image 1822
# Process for image 1823
# Process for image 1824
# Process for image 1825
# Process for image 1826
# Process for image 1827
# Process for image 1828
# Process for image 1829
# Process for image 1830
# Process for image 1831
# Process for image 1832
# Process for image 1833
# Process for image 1834
# Process for image 1835
# Process for image 1836
# Process for image 1837
# Process for image 1838
# Process for image 1839
# Process for image 1840
# Process for image 1841
# Process for image 1842
# Process for image 1843
# Process for image 1844
# Process for image 1845
# Process for image 1846
# Process for image 1847
# Process for image 1848
# Process for image 1849
# Process for image 1850
# Process for image 1851
# Process for image 1852
# Process for image 1853
# Process for image 1854
# Process for image 1855
# Process for image 1856
# Process for image 1857
# Process for image 1858
# Process for image 1859
# Process for image 1860
# Process for image 1861
# Process for image 1862
# Process for image 1863
# Process for image 1864
# Process for image 1865
# Process for image 1866
# Process for image 1867
# Process for image 1868
# Process for image 1869
# Process for image 1870
# Process for image 1871
# Process for image 1872
# Process for image 1873
# Process for image 1874
# Process for image 1875
# Process for image 1876
# Process for image 1877
# Process for image 1878
# Process for image 1879
# Process for image 1880
# Process for image 1881
# Process for image 1882
# Process for image 1883
# Process for image 1884
# Process for image 1885
# Process for image 1886
# Process for image 1887
# Process for image 1888
# Process for image 1889
# Process for image 1890
# Process for image 1891
# Process for image 1892
# Process for image 1893
# Process for image 1894
# Process for image 1895
# Process for image 1896
# Process for image 1897
# Process for image 1898
# Process for image 1899
# Process for image 1900
# Process for image 1901
# Process for image 1902
# Process for image 1903
# Process for image 1904
# Process for image 1905
# Process for image 1906
# Process for image 1907
# Process for image 1908
# Process for image 1909
# Process for image 1910
# Process for image 1911
# Process for image 1912
# Process for image 1913
# Process for image 1914
# Process for image 1915
# Process for image 1916
# Process for image 1917
# Process for image 1918
# Process for image 1919
# Process for image 1920
# Process for image 1921
# Process for image 1922
# Process for image 1923
# Process for image 1924
# Process for image 1925
# Process for image 1926
# Process for image 1927
# Process for image 1928
# Process for image 1929
# Process for image 1930
# Process for image 1931
# Process for image 1932
# Process for image 1933
# Process for image 1934
# Process for image 1935
# Process for image 1936
# Process for image 1937
# Process for image 1938
# Process for image 1939
# Process for image 1940
# Process for image 1941
# Process for image 1942
# Process for image 1943
# Process for image 1944
# Process for image 1945
# Process for image 1946
# Process for image 1947
# Process for image 1948
# Process for image 1949
# Process for image 1950
# Process for image 1951
# Process for image 1952
# Process for image 1953
# Process for image 1954
# Process for image 1955
# Process for image 1956
# Process for image 1957
# Process for image 1958
# Process for image 1959
# Process for image 1960
# Process for image 1961
# Process for image 1962
# Process for image 1963
# Process for image 1964
# Process for image 1965
# Process for image 1966
# Process for image 1967
# Process for image 1968
# Process for image 1969
# Process for image 1970
# Process for image 1971
# Process for image 1972
# Process for image 1973
# Process for image 1974
# Process for image 1975
# Process for image 1976
# Process for image 1977
# Process for image 1978
# Process for image 1979
# Process for image 1980
# Process for image 1981
# Process for image 1982
# Process for image 1983
# Process for image 1984
# Process for image 1985
# Process for image 1986
# Process for image 1987
# Process for image 1988
# Process for image 1989
# Process for image 1990
# Process for image 1991
# Process for image 1992
# Process for image 1993
# Process for image 1994
# Process for image 1995
# Process for image 1996
# Process for image 1997
# Process for image 1998
# Process for image 1999
# Process for image 2000
# Process for image 2001
# Process for image 2002
# Process for image 2003
# Process for image 2004
# Process for image 2005
# Process for image 2006
# Process for image 2007
# Process for image 2008
# Process for image 2009
# Process for image 2010
# Process for image 2011
# Process for image 2012
# Process for image 2013
# Process for image 2014
# Process for image 2015
# Process for image 2016
# Process for image 2017
# Process for image 2018
# Process for image 2019
# Process for image 2020
# Process for image 2021
# Process for image 2022
# Process for image 2023
# Process for image 2024
# Process for image 2025
# Process for image 2026
# Process for image 2027
# Process for image 2028
# Process for image 2029
# Process for image 2030
# Process for image 2031
# Process for image 2032
# Process for image 2033
# Process for image 2034
# Process for image 2035
# Process for image 2036
# Process for image 2037
# Process for image 2038
# Process for image 2039
# Process for image 2040
# Process for image 2041
# Process for image 2042
# Process for image 2043
# Process for image 2044
# Process for image 2045
# Process for image 2046
# Process for image 2047
# Process for image 2048
# Process for image 2049
# Process for image 2050
# Process for image 2051
# Process for image 2052
# Process for image 2053
# Process for image 2054
# Process for image 2055
# Process for image 2056
# Process for image 2057
# Process for image 2058
# Process for image 2059
# Process for image 2060
# Process for image 2061
# Process for image 2062
# Process for image 2063
# Process for image 2064
# Process for image 2065
# Process for image 2066
# Process for image 2067
# Process for image 2068
# Process for image 2069
# Process for image 2070
# Process for image 2071
# Process for image 2072
# Process for image 2073
# Process for image 2074
# Process for image 2075
# Process for image 2076
# Process for image 2077
# Process for image 2078
# Process for image 2079
# Process for image 2080
# Process for image 2081
# Process for image 2082
# Process for image 2083
# Process for image 2084
# Process for image 2085
# Process for image 2086
# Process for image 2087
# Process for image 2088
# Process for image 2089
# Process for image 2090
# Process for image 2091
# Process for image 2092
# Process for image 2093
# Process for image 2094
# Process for image 2095
# Process for image 2096
# Process for image 2097
# Process for image 2098
# Process for image 2099
# Process for image 2100
# Process for image 2101
# Process for image 2102
# Process for image 2103
# Process for image 2104
# Process for image 2105
# Process for image 2106
# Process for image 2107
# Process for image 2108
# Process for image 2109
# Process for image 2110
# Process for image 2111
# Process for image 2112
# Process for image 2113
# Process for image 2114
# Process for image 2115
# Process for image 2116
# Process for image 2117
# Process for image 2118
# Process for image 2119
# Process for image 2120
# Process for image 2121
# Process for image 2122
# Process for image 2123
# Process for image 2124
# Process for image 2125
# Process for image 2126
# Process for image 2127
# Process for image 2128
# Process for image 2129
# Process for image 2130
# Process for image 2131
# Process for image 2132
# Process for image 2133
# Process for image 2134
# ...
# Process for image 9306
# Process for image 9307
# Process for image 9308
# Process for image 9309
# Process for image 9310
# Process for image 9311
# Process for image 9312
# Process for image 9313
# Process for image 9314
# Process for image 9315
# Process for image 9316
# Process for image 9317
# Process for image 9318
# Process for image 9319
# Process for image 9320
# Process for image 9321
# Process for image 9322
# Process for image 9323
# Process for image 9324
# Process for image 9325
# Process for image 9326
# Process for image 9327
# Process for image 9328
# Process for image 9329
# Process for image 9330
# Process for image 9331
# Process for image 9332
# Process for image 9333
# Process for image 9334
# Process for image 9335
# Process for image 9336
# Process for image 9337
# Process for image 9338
# Process for image 9339
# Process for image 9340
# Process for image 9341
# Process for image 9342
# Process for image 9343
# Process for image 9344
# Process for image 9345
# Process for image 9346
# Process for image 9347
# Process for image 9348
# Process for image 9349
# Process for image 9350
# Process for image 9351
# Process for image 9352
# Process for image 9353
# Process for image 9354
# Process for image 9355
# Process for image 9356
# Process for image 9357
# Process for image 9358
# Process for image 9359
# Process for image 9360
# Process for image 9361
# Process for image 9362
# Process for image 9363
# Process for image 9364
# Process for image 9365
# Process for image 9366
# Process for image 9367
# Process for image 9368
# Process for image 9369
# Process for image 9370
# Process for image 9371
# Process for image 9372
# Process for image 9373
# Process for image 9374
# Process for image 9375
# Process for image 9376
# Process for image 9377
# Process for image 9378
# Process for image 9379
# Process for image 9380
# Process for image 9381
# Process for image 9382
# Process for image 9383
# Process for image 9384
# Process for image 9385
# Process for image 9386
# Process for image 9387
# Process for image 9388
# Process for image 9389
# Process for image 9390
# Process for image 9391
# Process for image 9392
# Process for image 9393
# Process for image 9394
# Process for image 9395
# Process for image 9396
# Process for image 9397
# Process for image 9398
# Process for image 9399
# Process for image 9400
# Process for image 9401
# Process for image 9402
# Process for image 9403
# Process for image 9404
# Process for image 9405
# Process for image 9406
# Process for image 9407
# Process for image 9408
# Process for image 9409
# Process for image 9410
# Process for image 9411
# Process for image 9412
# Process for image 9413
# Process for image 9414
# Process for image 9415
# Process for image 9416
# Process for image 9417
# Process for image 9418
# Process for image 9419
# Process for image 9420
# Process for image 9421
# Process for image 9422
# Process for image 9423
# Process for image 9424
# Process for image 9425
# Process for image 9426
# Process for image 9427
# Process for image 9428
# Process for image 9429
# Process for image 9430
# Process for image 9431
# Process for image 9432
# Process for image 9433
# Process for image 9434
# Process for image 9435
# Process for image 9436
# Process for image 9437
# Process for image 9438
# Process for image 9439
# Process for image 9440
# Process for image 9441
# Process for image 9442
# Process for image 9443
# Process for image 9444
# Process for image 9445
# Process for image 9446
# Process for image 9447
# Process for image 9448
# Process for image 9449
# Process for image 9450
# Process for image 9451
# Process for image 9452
# Process for image 9453
# Process for image 9454
# Process for image 9455
# Process for image 9456
# Process for image 9457
# Process for image 9458
# Process for image 9459
# Process for image 9460
# Process for image 9461
# Process for image 9462
# Process for image 9463
# Process for image 9464
# Process for image 9465
# Process for image 9466
# Process for image 9467
# Process for image 9468
# Process for image 9469
# Process for image 9470
# Process for image 9471
# Process for image 9472
# Process for image 9473
# Process for image 9474
# Process for image 9475
# Process for image 9476
# Process for image 9477
# Process for image 9478
# Process for image 9479
# Process for image 9480
# Process for image 9481
# Process for image 9482
# Process for image 9483
# Process for image 9484
# Process for image 9485
# Process for image 9486
# Process for image 9487
# Process for image 9488
# Process for image 9489
# Process for image 9490
# Process for image 9491
# Process for image 9492
# Process for image 9493
# Process for image 9494
# Process for image 9495
# Process for image 9496
# Process for image 9497
# Process for image 9498
# Process for image 9499
# Process for image 9500
# Process for image 9501
# Process for image 9502
# Process for image 9503
# Process for image 9504
# Process for image 9505
# Process for image 9506
# Process for image 9507
# Process for image 9508
# Process for image 9509
# Process for image 9510
# Process for image 9511
# Process for image 9512
# Process for image 9513
# Process for image 9514
# Process for image 9515
# Process for image 9516
# Process for image 9517
# Process for image 9518
# Process for image 9519
# Process for image 9520
# Process for image 9521
# Process for image 9522
# Process for image 9523
# Process for image 9524
# Process for image 9525
# Process for image 9526
# Process for image 9527
# Process for image 9528
# Process for image 9529
# Process for image 9530
# Process for image 9531
# Process for image 9532
# Process for image 9533
# Process for image 9534
# Process for image 9535
# Process for image 9536
# Process for image 9537
# Process for image 9538
# Process for image 9539
# Process for image 9540
# Process for image 9541
# Process for image 9542
# Process for image 9543
# Process for image 9544
# Process for image 9545
# Process for image 9546
# Process for image 9547
# Process for image 9548
# Process for image 9549
# Process for image 9550
# Process for image 9551
# Process for image 9552
# Process for image 9553
# Process for image 9554
# Process for image 9555
# Process for image 9556
# Process for image 9557
# Process for image 9558
# Process for image 9559
# Process for image 9560
# Process for image 9561
# Process for image 9562
# Process for image 9563
# Process for image 9564
# Process for image 9565
# Process for image 9566
# Process for image 9567
# Process for image 9568
# Process for image 9569
# Process for image 9570
# Process for image 9571
# Process for image 9572
# Process for image 9573
# Process for image 9574
# Process for image 9575
# Process for image 9576
# Process for image 9577
# Process for image 9578
# Process for image 9579
# Process for image 9580
# Process for image 9581
# Process for image 9582
# Process for image 9583
# Process for image 9584
# Process for image 9585
# Process for image 9586
# Process for image 9587
# Process for image 9588
# Process for image 9589
# Process for image 9590
# Process for image 9591
# Process for image 9592
# Process for image 9593
# Process for image 9594
# Process for image 9595
# Process for image 9596
# Process for image 9597
# Process for image 9598
# Process for image 9599
# Process for image 9600
# Process for image 9601
# Process for image 9602
# Process for image 9603
# Process for image 9604
# Process for image 9605
# Process for image 9606
# Process for image 9607
# Process for image 9608
# Process for image 9609
# Process for image 9610
# Process for image 9611
# Process for image 9612
# Process for image 9613
# Process for image 9614
# Process for image 9615
# Process for image 9616
# Process for image 9617
# Process for image 9618
# Process for image 9619
# Process for image 9620
# Process for image 9621
# Process for image 9622
# Process for image 9623
# Process for image 9624
# Process for image 9625
# Process for image 9626
# Process for image 9627
# Process for image 9628
# Process for image 9629
# Process for image 9630
# Process for image 9631
# Process for image 9632
# Process for image 9633
# Process for image 9634
# Process for image 9635
# Process for image 9636
# Process for image 9637
# Process for image 9638
# Process for image 9639
# Process for image 9640
# Process for image 9641
# Process for image 9642
# Process for image 9643
# Process for image 9644
# Process for image 9645
# Process for image 9646
# Process for image 9647
# Process for image 9648
# Process for image 9649
# Process for image 9650
# Process for image 9651
# Process for image 9652
# Process for image 9653
# Process for image 9654
# Process for image 9655
# Process for image 9656
# Process for image 9657
# Process for image 9658
# Process for image 9659
# Process for image 9660
# Process for image 9661
# Process for image 9662
# Process for image 9663
# Process for image 9664
# Process for image 9665
# Process for image 9666
# Process for image 9667
# Process for image 9668
# Process for image 9669
# Process for image 9670
# Process for image 9671
# Process for image 9672
# Process for image 9673
# Process for image 9674
# Process for image 9675
# Process for image 9676
# Process for image 9677
# Process for image 9678
# Process for image 9679
# Process for image 9680
# Process for image 9681
# Process for image 9682
# Process for image 9683
# Process for image 9684
# Process for image 9685
# Process for image 9686
# Process for image 9687
# Process for image 9688
# Process for image 9689
# Process for image 9690
# Process for image 9691
# Process for image 9692
# Process for image 9693
# Process for image 9694
# Process for image 9695
# Process for image 9696
# Process for image 9697
# Process for image 9698
# Process for image 9699
# Process for image 9700
# Process for image 9701
# Process for image 9702
# Process for image 9703
# Process for image 9704
# Process for image 9705
# Process for image 9706
# Process for image 9707
# Process for image 9708
# Process for image 9709
# Process for image 9710
# Process for image 9711
# Process for image 9712
# Process for image 9713
# Process for image 9714
# Process for image 9715
# Process for image 9716
# Process for image 9717
# Process for image 9718
# Process for image 9719
# Process for image 9720
# Process for image 9721
# Process for image 9722
# Process for image 9723
# Process for image 9724
# Process for image 9725
# Process for image 9726
# Process for image 9727
# Process for image 9728
# Process for image 9729
# Process for image 9730
# Process for image 9731
# Process for image 9732
# Process for image 9733
# Process for image 9734
# Process for image 9735
# Process for image 9736
# Process for image 9737
# Process for image 9738
# Process for image 9739
# Process for image 9740
# Process for image 9741
# Process for image 9742
# Process for image 9743
# Process for image 9744
# Process for image 9745
# Process for image 9746
# Process for image 9747
# Process for image 9748
# Process for image 9749
# Process for image 9750
# Process for image 9751
# Process for image 9752
# Process for image 9753
# Process for image 9754
# Process for image 9755
# Process for image 9756
# Process for image 9757
# Process for image 9758
# Process for image 9759
# Process for image 9760
# Process for image 9761
# Process for image 9762
# Process for image 9763
# Process for image 9764
# Process for image 9765
# Process for image 9766
# Process for image 9767
# Process for image 9768
# Process for image 9769
# Process for image 9770
# Process for image 9771
# Process for image 9772
# Process for image 9773
# Process for image 9774
# Process for image 9775
# Process for image 9776
# Process for image 9777
# Process for image 9778
# Process for image 9779
# Process for image 9780
# Process for image 9781
# Process for image 9782
# Process for image 9783
# Process for image 9784
# Process for image 9785
# Process for image 9786
# Process for image 9787
# Process for image 9788
# Process for image 9789
# Process for image 9790
# Process for image 9791
# Process for image 9792
# Process for image 9793
# Process for image 9794
# Process for image 9795
# Process for image 9796
# Process for image 9797
# Process for image 9798
# Process for image 9799
# Process for image 9800
# Process for image 9801
# Process for image 9802
# Process for image 9803
# Process for image 9804
# Process for image 9805
# Process for image 9806
# Process for image 9807
# Process for image 9808
# Process for image 9809
# Process for image 9810
# Process for image 9811
# Process for image 9812
# Process for image 9813
# Process for image 9814
# Process for image 9815
# Process for image 9816
# Process for image 9817
# Process for image 9818
# Process for image 9819
# Process for image 9820
# Process for image 9821
# Process for image 9822
# Process for image 9823
# Process for image 9824
# Process for image 9825
# Process for image 9826
# Process for image 9827
# Process for image 9828
# Process for image 9829
# Process for image 9830
# Process for image 9831
# Process for image 9832
# Process for image 9833
# Process for image 9834
# Process for image 9835
# Process for image 9836
# Process for image 9837
# Process for image 9838
# Process for image 9839
# Process for image 9840
# Process for image 9841
# Process for image 9842
# Process for image 9843
# Process for image 9844
# Process for image 9845
# Process for image 9846
# Process for image 9847
# Process for image 9848
# Process for image 9849
# Process for image 9850
# Process for image 9851
# Process for image 9852
# Process for image 9853
# Process for image 9854
# Process for image 9855
# Process for image 9856
# Process for image 9857
# Process for image 9858
# Process for image 9859
# Process for image 9860
# Process for image 9861
# Process for image 9862
# Process for image 9863
# Process for image 9864
# Process for image 9865
# Process for image 9866
# Process for image 9867
# Process for image 9868
# Process for image 9869
# Process for image 9870
# Process for image 9871
# Process for image 9872
# Process for image 9873
# Process for image 9874
# Process for image 9875
# Process for image 9876
# Process for image 9877
# Process for image 9878
# Process for image 9879
# Process for image 9880
# Process for image 9881
# Process for image 9882
# Process for image 9883
# Process for image 9884
# Process for image 9885
# Process for image 9886
# Process for image 9887
# Process for image 9888
# Process for image 9889
# Process for image 9890
# Process for image 9891
# Process for image 9892
# Process for image 9893
# Process for image 9894
# Process for image 9895
# Process for image 9896
# Process for image 9897
# Process for image 9898
# Process for image 9899
# Process for image 9900
# Process for image 9901
# Process for image 9902
# Process for image 9903
# Process for image 9904
# Process for image 9905
# Process for image 9906
# Process for image 9907
# Process for image 9908
# Process for image 9909
# Process for image 9910
# Process for image 9911
# Process for image 9912
# Process for image 9913
# Process for image 9914
# Process for image 9915
# Process for image 9916
# Process for image 9917
# Process for image 9918
# Process for image 9919
# Process for image 9920
# Process for image 9921
# Process for image 9922
# Process for image 9923
# Process for image 9924
# Process for image 9925
# Process for image 9926
# Process for image 9927
# Process for image 9928
# Process for image 9929
# Process for image 9930
# Process for image 9931
# Process for image 9932
# Process for image 9933
# Process for image 9934
# Process for image 9935
# Process for image 9936
# Process for image 9937
# Process for image 9938
# Process for image 9939
# Process for image 9940
# Process for image 9941
# Process for image 9942
# Process for image 9943
# Process for image 9944
# Process for image 9945
# Process for image 9946
# Process for image 9947
# Process for image 9948
# Process for image 9949
# Process for image 9950
# Process for image 9951
# Process for image 9952
# Process for image 9953
# Process for image 9954
# Process for image 9955
# Process for image 9956
# Process for image 9957
# Process for image 9958
# Process for image 9959
# Process for image 9960
# Process for image 9961
# Process for image 9962
# Process for image 9963
# Process for image 9964
# Process for image 9965
# Process for image 9966
# Process for image 9967
# Process for image 9968
# Process for image 9969
# Process for image 9970
# Process for image 9971
# Process for image 9972
# Process for image 9973
# Process for image 9974
# Process for image 9975
# Process for image 9976
# Process for image 9977
# Process for image 9978
# Process for image 9979
# Process for image 9980
# Process for image 9981
# Process for image 9982
# Process for image 9983
# Process for image 9984
# Process for image 9985
# Process for image 9986
# Process for image 9987
# Process for image 9988
# Process for image 9989
# Process for image 9990
# Process for image 9991
# Process for image 9992
# Process for image 9993
# Process for image 9994
# Process for image 9995
# Process for image 9996
# Process for image 9997
# Process for image 9998
# Process for image 9999
# Total time: 1538.0868163108826

# %%
new_row = {
    'Framework': ['ezkl-resource (pytorch)'],
    'Architecture': ['Input-Conv2d-Conv2d-Dense-Dense (196x5x11x80x10'],
    '# Layers': [5],
    '# Parameters': [4966],
    'Testing Size': [test_size],
    'Accuracy Loss (%)': [loss_/test_size*100],
    'Avg Memory Usage (MB)': [sum(mem_usage_) / len(mem_usage_)],
    'Std Memory Usage': [pd.Series(mem_usage_).std()],
    'Avg Proving Time (s)': [sum(time_cost_) / len(time_cost_)],
    'Std Proving Time': [pd.Series(time_cost_).std()]
}

new_row_df = pd.DataFrame(new_row)

# %%
df = pd.read_csv(csv_path)

df = pd.concat([df, new_row_df], ignore_index=True)
df.to_csv(csv_path, index=False)
df
# Out:
#                     Framework  \
# 0              opml (pytorch)
# 1              opml (pytorch)
# 2              opml (pytorch)
# 3   circomlib-ml (tensorflow)
# 4   circomlib-ml (tensorflow)
# 5   circomlib-ml (tensorflow)
# 6           zkml (tensorflow)
# 7           zkml (tensorflow)
# 8           zkml (tensorflow)
# 9           zkml (tensorflow)
# 10             ezkl (pytorch)
# 11             ezkl (pytorch)
# 12             ezkl (pytorch)
# 13    ezkl-accuracy (pytorch)
# 14    ezkl-resource (pytorch)
#
#                                        Architecture  # Layers  # Parameters  \
# 0                     Input-Dense-Dense (196x25x10)         3          5185
# 1            Input-Dense-Dense-Dense (196x24x14x10)         4          5228
# 2                     Input-Dense-Dense (784x56x10)         3         44543
# 3                     Input-Dense-Dense (196x25x10)         3          5185
# 4            Input-Dense-Dense-Dense (196x24x14x10)         4          5228
# 5                     Input-Dense-Dense (784x56x10)         3         44543
# 6                     Input-Dense-Dense (196x25x10)         3          5185
# 7            Input-Dense-Dense-Dense (196x24x14x10)         4          5228
# 8                     Input-Dense-Dense (784x56x10)         3         44543
# 9           Input-Conv2d-Conv2d-Dense (784x6x16x10)         4          5142
# 10                    Input-Dense-Dense (196x25x10)         3          5185
# 11           Input-Dense-Dense-Dense (196x24x14x10)         4          5228
# 12                    Input-Dense-Dense (784x56x10)         3         44543
# 13                    Input-Dense-Dense (196x25x10)         3          5185
# 14  Input-Conv2d-Conv2d-Dense-Dense (196x5x11x80x10         5          4966
#
#     Testing Size  Accuracy Loss (%)  Avg Memory Usage (MB)  Std Memory Usage  \
# 0           5000               3.52              74.351948          1.419725
# 1           5000               3.42              74.450789          1.491530
# 2           2500               0.72              89.120883          2.254392
# 3           2500               0.00             998.735128          8.040170
# 4           2500               0.88             315.435559          1.690681
# 5           2500               0.04            2328.322411         34.436486
# 6           1000               0.10            2334.295629         12.335301
# 7           2500               0.00            2338.480847         13.611456
# 8           1000               0.00            2357.363156         11.750076
# 9           1000               0.10            1764.619016         12.589448
# 10         10000               4.11              91.608069          0.756873
# 11         10000              15.71              91.589901          0.742728
# 12         10000               4.96             222.911670          3.971043
# 13          1000               0.00            2636.281324       1081.227782
# 14         10000               0.00              50.375698          0.237119
#
#     Avg Proving Time (s)  Std Proving Time
# 0               0.809440          0.074357
# 1               0.829767          0.085084
# 2               3.609974          0.421732
# 3               1.169482          0.108491
# 4               0.452942          0.031613
# 5               2.351284          0.147113
# 6              21.263430          0.294183
# 7              22.168541          0.528263
# 8              22.012543          0.317096
# 9              15.618183          0.825017
# 10              0.660479          0.025701
# 11              0.693572          0.024197
# 12              2.657050          0.161535
# 13             19.525911          8.710526
# 14              0.153775          0.009969
